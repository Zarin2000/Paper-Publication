# %% [raw]
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load
#
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#
# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
#
# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="PhYPBAynLidVpEOeKCPW")
project = rf.workspace("apple9leaf").project("appleleaf")
dataset = project.version(3).download("folder")
# Out:
# Collecting roboflow
#   Obtaining dependency information for roboflow from https://files.pythonhosted.org/packages/e5/0c/b5a94933f815630171f1ed555ca180325c80d34fc6a42dfb1de4618bfdae/roboflow-1.1.16-py3-none-any.whl.metadata
#   Downloading roboflow-1.1.16-py3-none-any.whl.metadata (9.3 kB)
# Collecting certifi==2023.7.22 (from roboflow)
#   Obtaining dependency information for certifi==2023.7.22 from https://files.pythonhosted.org/packages/4c/dd/2234eab22353ffc7d94e8d13177aaa050113286e93e7b40eae01fbf7c3d9/certifi-2023.7.22-py3-none-any.whl.metadata
#   Downloading certifi-2023.7.22-py3-none-any.whl.metadata (2.2 kB)
# Collecting chardet==4.0.0 (from roboflow)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 2.1 MB/s eta 0:00:00a 0:00:01
# Collecting cycler==0.10.0 (from roboflow)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting idna==2.10 (from roboflow)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.4.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from roboflow) (3.7.4)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.24.3)
# Collecting opencv-python-headless==4.8.0.74 (from roboflow)
#   Obtaining dependency information for opencv-python-headless==4.8.0.74 from https://files.pythonhosted.org/packages/76/02/f128517f3ade4bb5f71e2afd8461dba70e3f466ce745fa1fd1fade9ad1b7/opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from roboflow) (10.1.0)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.10/site-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.16.0)
# Collecting supervision (from roboflow)
#   Obtaining dependency information for supervision from https://files.pythonhosted.org/packages/b9/c5/8bb6e9f51e5e8cc9b80fcb5f30a2b7289c0ad94d848c08ef3691fb4196f1/supervision-0.17.1-py3-none-any.whl.metadata
#   Downloading supervision-0.17.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: urllib3>=1.26.6 in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.26.15)
# Requirement already satisfied: tqdm>=4.41.0 in /opt/conda/lib/python3.10/site-packages (from roboflow) (4.66.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in /opt/conda/lib/python3.10/site-packages (from roboflow) (0.10.1)
# Collecting python-magic (from roboflow)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->roboflow) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->roboflow) (4.42.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->roboflow) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->roboflow) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->roboflow) (3.2.0)
# Requirement already satisfied: scipy>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from supervision->roboflow) (1.11.4)
# Downloading roboflow-1.1.16-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.9/69.9 kB 7.2 MB/s eta 0:00:00
# Downloading certifi-2023.7.22-py3-none-any.whl (158 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 9.1 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 20.4 MB/s eta 0:00:0000:0100:01
# Downloading supervision-0.17.1-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 8.4 MB/s eta 0:00:00
# Installing collected packages: python-magic, opencv-python-headless, idna, cycler, chardet, certifi, supervision, roboflow
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
#     Uninstalling opencv-python-headless-4.8.1.78:
#       Successfully uninstalled opencv-python-headless-4.8.1.78
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.11.17
#     Uninstalling certifi-2023.11.17:
#       Successfully uninstalled certifi-2023.11.17
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyterlab 4.0.5 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.0.1 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.0.1 requires jupyterlab<5.0.0a0,>=4.0.6, but you have jupyterlab 4.0.5 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# tensorflowjs 4.14.0 requires packaging~=23.1, but you have packaging 21.3 which is incompatible.
# ydata-profiling 4.5.1 requires numpy<1.24,>=1.16.0, but you have numpy 1.24.3 which is incompatible.
# Successfully installed certifi-2023.7.22 chardet-4.0.0 cycler-0.10.0 idna-2.10 opencv-python-headless-4.8.0.74 python-magic-0.4.27 roboflow-1.1.16 supervision-0.17.1
# A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in AppleLeaf-3 to folder:: 100%|██████████| 98669/98669 [00:01<00:00, 49403.04it/s]
# Extracting Dataset Version Zip to AppleLeaf-3 in folder:: 100%|██████████| 11524/11524 [00:01<00:00, 9308.36it/s]

# %%
import numpy as np
import pandas as pd
import os
from sklearn.metrics import classification_report
import seaborn as sn
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from tqdm import tqdm

class_names= ['Alternaria leaf spot', 'Brown spot', 'Frogeye leaf spot', 'Grey spot', 'Health', 'Mosaic',
              'Powdery mildew', 'Rust', 'Scab']

class_names_labels={class_name:i for i, class_name in enumerate(class_names)}

print(class_names_labels)

nb_classes=len(class_names)

IMAGE_SIZE=(224,224)

def load_data():
    direct='/kaggle/working/AppleLeaf-3/'
    category=['train','valid','test']

    output=[]

    for cat in category:
      path=os.path.join(direct,cat)
      print(path)

      images=[]
      labels=[]

      for folder in os.listdir(path):
        print("folder:",folder)
        label= class_names_labels[folder]

        #Iterating each image
        for fle in os.listdir(os.path.join(path,folder)):

          img_path=os.path.join(os.path.join(path,folder),fle)

          image=cv2.imread(img_path)
          image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
          image=cv2.resize(image,IMAGE_SIZE)

          images.append(image)
          labels.append(label)

      images=np.array(images,dtype='float32')
      labels=np.array(labels,dtype='int32')

      output.append((images,labels))
    #print(type(output[0]))
    return output

(train_images,train_lables), (valid_images,valid_lables), (test_images,test_lables) = load_data()
# Out:
# {'Alternaria leaf spot': 0, 'Brown spot': 1, 'Frogeye leaf spot': 2, 'Grey spot': 3, 'Health': 4, 'Mosaic': 5, 'Powdery mildew': 6, 'Rust': 7, 'Scab': 8}
# /kaggle/working/AppleLeaf-3/train
# folder: Brown spot
# folder: Scab
# folder: Alternaria leaf spot
# folder: Grey spot
# folder: Health
# folder: Mosaic
# folder: Frogeye leaf spot
# folder: Rust
# folder: Powdery mildew
# /kaggle/working/AppleLeaf-3/valid
# folder: Brown spot
# folder: Scab
# folder: Alternaria leaf spot
# folder: Grey spot
# folder: Health
# folder: Mosaic
# folder: Frogeye leaf spot
# folder: Rust
# folder: Powdery mildew
# /kaggle/working/AppleLeaf-3/test
# folder: Brown spot
# folder: Scab
# folder: Alternaria leaf spot
# folder: Grey spot
# folder: Health
# folder: Mosaic
# folder: Frogeye leaf spot
# folder: Rust
# folder: Powdery mildew

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate,Flatten, Dense, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
import keras

model = Sequential()
model.add(Conv2D(16, (3, 3), activation='relu',padding='valid', input_shape=(224, 224, 3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(64, (3, 3),padding='valid', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(256, (3, 3),padding='valid', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(384, (3, 3),padding='valid', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3),padding='valid', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(64, (3, 3),padding='valid', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(16, (3, 3),padding='valid', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(2, 2))


model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(9, activation='softmax'))  # Assuming 5 classes
model.summary()

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model_checkpoint_callback = keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=30,restore_best_weights=True)

history = model.fit(train_images, train_lables, batch_size=8, epochs=250,

        validation_data=(valid_images, valid_lables), callbacks=[model_checkpoint_callback])

test_loss=model.evaluate(test_images,test_lables)
predictions=model.predict(test_images)
pred_lables=np.argmax(predictions,axis=1)
print(classification_report(test_lables,pred_lables))

def plot_accuracy_loss(history):
  fig=plt.figure(figsize=(10,5))

  #plot accuarcy
  plt.subplot(221)
  plt.plot(history.history['accuracy'],label='acc')
  plt.plot(history.history['val_accuracy'],label='val_acc')
  plt.title('train_acc vs val_acc')
  plt.ylabel("accuracy")
  plt.xlabel("epochs")
  plt.legend()


  #plot loss
  plt.subplot(222)
  plt.plot(history.history['loss'],label='loss')
  plt.plot(history.history['val_loss'],label='val_loss')
  plt.title('train_loss vs val_loss')
  plt.ylabel("loss")
  plt.xlabel("epochs")
  plt.legend()

  plt.show()

plot_accuracy_loss(history)


import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from itertools import cycle
from sklearn.metrics import roc_auc_score
from tensorflow.keras.models import load_model

# Assuming you have test data, labels, and predictions
# test_data = ...
# test_labels = ...
# test_predictions = ...

# Number of classes
num_classes = 9

# Map class names to their corresponding numbers
class_mapping = {
'Alternaria leaf spot': 0, 'Brown spot': 1, 'Frogeye leaf spot': 2, 'Grey spot': 3, 'Health': 4, 'Mosaic': 5, 'Powdery mildew': 6, 'Rust': 7, 'Scab': 8
}

# Reverse the mapping to get class names from numbers
class_names = {v: k for k, v in class_mapping.items()}

# Binarize the labels
y_test = label_binarize(test_lables, classes=range(num_classes))

# Load your Keras model
# model = load_model('your_model_path')

# Predict probabilities
y_score = model.predict(test_images)

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute macro-average ROC curve and ROC area
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(num_classes)]))

# Interpolate ROC curves at these points
mean_tpr = np.zeros_like(all_fpr)
for i in range(num_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Average and compute AUC
mean_tpr /= num_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot ROC curves
plt.figure(figsize=(10, 8))

# Plot individual ROC curves
colors = cycle(['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'black', 'purple', 'orange'])
for i, color in zip(range(num_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2, label='ROC curve (area = {:.2f}) for class {}'.format(roc_auc[i], class_names[i]))

# Plot macro-average ROC curve
plt.plot(fpr["macro"], tpr["macro"], color='deeppink', linestyle=':', linewidth=4, label='Macro-average ROC curve (area = {:.2f})'.format(roc_auc["macro"]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()


import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn import metrics

def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)
    cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]  # Normalize

    plt.figure(figsize=(len(class_names) + 2, len(class_names)))
    sns.set(font_scale=1.2)
    sns.heatmap(cm_norm, annot=True, fmt=".2f", cmap="Blues", linewidths=.5, square=True,
                xticklabels=class_names, yticklabels=class_names)

    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix')

    plt.show()

# Example usage:
# Replace y_true and y_pred with your actual and predicted labels
# Replace class_names with your class names
y_true = test_lables  # Replace with your actual labels
y_pred = pred_lables  # Replace with your predicted labels
class_names= ['Alternaria leaf spot', 'Brown spot', 'Frogeye leaf spot', 'Grey spot', 'Health', 'Mosaic',
              'Powdery mildew', 'Rust', 'Scab']  # Replace with your class names

plot_confusion_matrix(y_true, y_pred, class_names)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 16)      448
#
#  batch_normalization (Batch  (None, 222, 222, 16)      64
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 111, 111, 16)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      9280
#
#  batch_normalization_1 (Bat  (None, 109, 109, 64)      256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 54, 54, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 256)       147712
#
#  batch_normalization_2 (Bat  (None, 52, 52, 256)       1024
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 26, 26, 256)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 384)       885120
#
#  batch_normalization_3 (Bat  (None, 24, 24, 384)       1536
#  chNormalization)
#
#  conv2d_4 (Conv2D)           (None, 22, 22, 256)       884992
#
#  batch_normalization_4 (Bat  (None, 22, 22, 256)       1024
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 11, 11, 256)       0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 9, 9, 64)          147520
#
#  batch_normalization_5 (Bat  (None, 9, 9, 64)          256
#  chNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 4, 4, 64)          0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 2, 2, 16)          9232
#
#  batch_normalization_6 (Bat  (None, 2, 2, 16)          64
#  chNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 1, 1, 16)          0
#  g2D)
#
#  flatten (Flatten)           (None, 16)                0
#
#  dense (Dense)               (None, 128)               2176
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 9)                 585
#
# =================================================================
# Total params: 2099545 (8.01 MB)
# Trainable params: 2097433 (8.00 MB)
# Non-trainable params: 2112 (8.25 KB)
# _________________________________________________________________
# Epoch 1/250
# 1326/1326 [==============================] - 43s 25ms/step - loss: 1.4428 - accuracy: 0.4387 - val_loss: 1.2217 - val_accuracy: 0.5374
# Epoch 2/250
# 1326/1326 [==============================] - 34s 25ms/step - loss: 1.0962 - accuracy: 0.5914 - val_loss: 0.7665 - val_accuracy: 0.7370
# Epoch 3/250
# 1326/1326 [==============================] - 35s 26ms/step - loss: 0.8970 - accuracy: 0.6793 - val_loss: 1.0504 - val_accuracy: 0.6372
# Epoch 4/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.7245 - accuracy: 0.7483 - val_loss: 0.6544 - val_accuracy: 0.7846
# Epoch 5/250
# 1326/1326 [==============================] - 35s 26ms/step - loss: 0.6014 - accuracy: 0.7954 - val_loss: 0.3915 - val_accuracy: 0.8821
# Epoch 6/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.5197 - accuracy: 0.8240 - val_loss: 0.8788 - val_accuracy: 0.7075
# Epoch 7/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.4636 - accuracy: 0.8421 - val_loss: 0.5069 - val_accuracy: 0.7937
# Epoch 8/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.4309 - accuracy: 0.8533 - val_loss: 0.4836 - val_accuracy: 0.8299
# Epoch 9/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.3848 - accuracy: 0.8714 - val_loss: 0.3410 - val_accuracy: 0.8798
# Epoch 10/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.3404 - accuracy: 0.8865 - val_loss: 0.2826 - val_accuracy: 0.9138
# Epoch 11/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.3240 - accuracy: 0.8906 - val_loss: 0.2778 - val_accuracy: 0.8980
# Epoch 12/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.3068 - accuracy: 0.8956 - val_loss: 0.3270 - val_accuracy: 0.9138
# Epoch 13/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.2665 - accuracy: 0.9112 - val_loss: 0.3139 - val_accuracy: 0.8934
# Epoch 14/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.2598 - accuracy: 0.9142 - val_loss: 0.9627 - val_accuracy: 0.7619
# Epoch 15/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.2458 - accuracy: 0.9194 - val_loss: 0.3670 - val_accuracy: 0.9048
# Epoch 16/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.2203 - accuracy: 0.9296 - val_loss: 0.3370 - val_accuracy: 0.9002
# Epoch 17/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.2068 - accuracy: 0.9299 - val_loss: 0.2682 - val_accuracy: 0.9093
# Epoch 18/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.1958 - accuracy: 0.9358 - val_loss: 0.3343 - val_accuracy: 0.8934
# Epoch 19/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.1678 - accuracy: 0.9448 - val_loss: 0.2747 - val_accuracy: 0.9138
# Epoch 20/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.1555 - accuracy: 0.9491 - val_loss: 0.3518 - val_accuracy: 0.8980
# Epoch 21/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.1471 - accuracy: 0.9478 - val_loss: 0.3573 - val_accuracy: 0.9025
# Epoch 22/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.1463 - accuracy: 0.9531 - val_loss: 0.4915 - val_accuracy: 0.8639
# Epoch 23/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.1373 - accuracy: 0.9544 - val_loss: 0.4084 - val_accuracy: 0.8844
# Epoch 24/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.1274 - accuracy: 0.9554 - val_loss: 0.6351 - val_accuracy: 0.8345
# Epoch 25/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.1196 - accuracy: 0.9598 - val_loss: 0.4045 - val_accuracy: 0.9048
# Epoch 26/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.1052 - accuracy: 0.9649 - val_loss: 0.2748 - val_accuracy: 0.9116
# Epoch 27/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.1174 - accuracy: 0.9629 - val_loss: 0.4024 - val_accuracy: 0.9002
# Epoch 28/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.1038 - accuracy: 0.9655 - val_loss: 0.3106 - val_accuracy: 0.9229
# Epoch 29/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.1001 - accuracy: 0.9663 - val_loss: 0.3896 - val_accuracy: 0.8844
# Epoch 30/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.1078 - accuracy: 0.9663 - val_loss: 0.4234 - val_accuracy: 0.8866
# Epoch 31/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0982 - accuracy: 0.9672 - val_loss: 0.3368 - val_accuracy: 0.9116
# Epoch 32/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0883 - accuracy: 0.9711 - val_loss: 0.3530 - val_accuracy: 0.9048
# Epoch 33/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0882 - accuracy: 0.9707 - val_loss: 0.3975 - val_accuracy: 0.8980
# Epoch 34/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0816 - accuracy: 0.9735 - val_loss: 0.3783 - val_accuracy: 0.9025
# Epoch 35/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0777 - accuracy: 0.9742 - val_loss: 0.4530 - val_accuracy: 0.8912
# Epoch 36/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0697 - accuracy: 0.9757 - val_loss: 0.4412 - val_accuracy: 0.9138
# Epoch 37/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0714 - accuracy: 0.9763 - val_loss: 0.3942 - val_accuracy: 0.9048
# Epoch 38/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0777 - accuracy: 0.9754 - val_loss: 0.4000 - val_accuracy: 0.9161
# Epoch 39/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0643 - accuracy: 0.9788 - val_loss: 0.3122 - val_accuracy: 0.9229
# Epoch 40/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0724 - accuracy: 0.9751 - val_loss: 0.3623 - val_accuracy: 0.9070
# Epoch 41/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0652 - accuracy: 0.9778 - val_loss: 0.4709 - val_accuracy: 0.9048
# Epoch 42/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0620 - accuracy: 0.9797 - val_loss: 0.4184 - val_accuracy: 0.9093
# Epoch 43/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0703 - accuracy: 0.9777 - val_loss: 0.5583 - val_accuracy: 0.8866
# Epoch 44/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0643 - accuracy: 0.9794 - val_loss: 0.5060 - val_accuracy: 0.8934
# Epoch 45/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0576 - accuracy: 0.9806 - val_loss: 0.4714 - val_accuracy: 0.9138
# Epoch 46/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0635 - accuracy: 0.9795 - val_loss: 0.3523 - val_accuracy: 0.9274
# Epoch 47/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0585 - accuracy: 0.9803 - val_loss: 0.3312 - val_accuracy: 0.9116
# Epoch 48/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0630 - accuracy: 0.9805 - val_loss: 0.3307 - val_accuracy: 0.9138
# Epoch 49/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0539 - accuracy: 0.9830 - val_loss: 0.4141 - val_accuracy: 0.9025
# Epoch 50/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0493 - accuracy: 0.9834 - val_loss: 0.4327 - val_accuracy: 0.9252
# Epoch 51/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0582 - accuracy: 0.9827 - val_loss: 0.3466 - val_accuracy: 0.9206
# Epoch 52/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0509 - accuracy: 0.9840 - val_loss: 0.3645 - val_accuracy: 0.9138
# Epoch 53/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0568 - accuracy: 0.9805 - val_loss: 0.3865 - val_accuracy: 0.9025
# Epoch 54/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0511 - accuracy: 0.9840 - val_loss: 0.3523 - val_accuracy: 0.9206
# Epoch 55/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0505 - accuracy: 0.9844 - val_loss: 0.3234 - val_accuracy: 0.9093
# Epoch 56/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0448 - accuracy: 0.9851 - val_loss: 0.3420 - val_accuracy: 0.9206
# Epoch 57/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0508 - accuracy: 0.9824 - val_loss: 0.4625 - val_accuracy: 0.9002
# Epoch 58/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0463 - accuracy: 0.9852 - val_loss: 0.3583 - val_accuracy: 0.9184
# Epoch 59/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0420 - accuracy: 0.9868 - val_loss: 0.3325 - val_accuracy: 0.9206
# Epoch 60/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0429 - accuracy: 0.9873 - val_loss: 0.3301 - val_accuracy: 0.9342
# Epoch 61/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0472 - accuracy: 0.9844 - val_loss: 0.4324 - val_accuracy: 0.8980
# Epoch 62/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0454 - accuracy: 0.9849 - val_loss: 0.3884 - val_accuracy: 0.9252
# Epoch 63/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0344 - accuracy: 0.9891 - val_loss: 0.3981 - val_accuracy: 0.9070
# Epoch 64/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0416 - accuracy: 0.9868 - val_loss: 0.3799 - val_accuracy: 0.9229
# Epoch 65/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0375 - accuracy: 0.9890 - val_loss: 0.3767 - val_accuracy: 0.9252
# Epoch 66/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0506 - accuracy: 0.9837 - val_loss: 0.3149 - val_accuracy: 0.9252
# Epoch 67/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0408 - accuracy: 0.9899 - val_loss: 0.3595 - val_accuracy: 0.9184
# Epoch 68/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0382 - accuracy: 0.9885 - val_loss: 0.3392 - val_accuracy: 0.9320
# Epoch 69/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0484 - accuracy: 0.9857 - val_loss: 0.3321 - val_accuracy: 0.9116
# Epoch 70/250
# 1326/1326 [==============================] - 35s 26ms/step - loss: 0.0369 - accuracy: 0.9881 - val_loss: 0.4406 - val_accuracy: 0.8957
# Epoch 71/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0432 - accuracy: 0.9866 - val_loss: 0.3831 - val_accuracy: 0.9184
# Epoch 72/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0390 - accuracy: 0.9884 - val_loss: 0.2786 - val_accuracy: 0.9388
# Epoch 73/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0363 - accuracy: 0.9892 - val_loss: 0.3535 - val_accuracy: 0.9274
# Epoch 74/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0486 - accuracy: 0.9848 - val_loss: 0.4385 - val_accuracy: 0.9002
# Epoch 75/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0337 - accuracy: 0.9892 - val_loss: 0.3624 - val_accuracy: 0.9206
# Epoch 76/250
# 1326/1326 [==============================] - 35s 26ms/step - loss: 0.0271 - accuracy: 0.9926 - val_loss: 0.4139 - val_accuracy: 0.9274
# Epoch 77/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0400 - accuracy: 0.9876 - val_loss: 0.3210 - val_accuracy: 0.9388
# Epoch 78/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0328 - accuracy: 0.9897 - val_loss: 0.4566 - val_accuracy: 0.9138
# Epoch 79/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0334 - accuracy: 0.9896 - val_loss: 0.4072 - val_accuracy: 0.9184
# Epoch 80/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0373 - accuracy: 0.9887 - val_loss: 0.4210 - val_accuracy: 0.9025
# Epoch 81/250
# 1326/1326 [==============================] - 35s 26ms/step - loss: 0.0346 - accuracy: 0.9891 - val_loss: 0.5455 - val_accuracy: 0.9138
# Epoch 82/250
# 1326/1326 [==============================] - 35s 26ms/step - loss: 0.0304 - accuracy: 0.9892 - val_loss: 0.5500 - val_accuracy: 0.9048
# Epoch 83/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0389 - accuracy: 0.9876 - val_loss: 0.4122 - val_accuracy: 0.9161
# Epoch 84/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0297 - accuracy: 0.9901 - val_loss: 0.3246 - val_accuracy: 0.9388
# Epoch 85/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0361 - accuracy: 0.9893 - val_loss: 0.3573 - val_accuracy: 0.9206
# Epoch 86/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0306 - accuracy: 0.9910 - val_loss: 0.4476 - val_accuracy: 0.9161
# Epoch 87/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0345 - accuracy: 0.9893 - val_loss: 0.3552 - val_accuracy: 0.9206
# Epoch 88/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0381 - accuracy: 0.9881 - val_loss: 0.5167 - val_accuracy: 0.9002
# Epoch 89/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0270 - accuracy: 0.9911 - val_loss: 0.5096 - val_accuracy: 0.9093
# Epoch 90/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0375 - accuracy: 0.9882 - val_loss: 0.3992 - val_accuracy: 0.9138
# Epoch 91/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0316 - accuracy: 0.9899 - val_loss: 0.3815 - val_accuracy: 0.9274
# Epoch 92/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0296 - accuracy: 0.9908 - val_loss: 0.4340 - val_accuracy: 0.9184
# Epoch 93/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0344 - accuracy: 0.9893 - val_loss: 0.3250 - val_accuracy: 0.9229
# Epoch 94/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0261 - accuracy: 0.9921 - val_loss: 0.4381 - val_accuracy: 0.9161
# Epoch 95/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0342 - accuracy: 0.9887 - val_loss: 0.3813 - val_accuracy: 0.9252
# Epoch 96/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0278 - accuracy: 0.9907 - val_loss: 0.3246 - val_accuracy: 0.9365
# Epoch 97/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0263 - accuracy: 0.9921 - val_loss: 0.3751 - val_accuracy: 0.9184
# Epoch 98/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0304 - accuracy: 0.9905 - val_loss: 0.4566 - val_accuracy: 0.9206
# Epoch 99/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0242 - accuracy: 0.9926 - val_loss: 0.5293 - val_accuracy: 0.9161
# Epoch 100/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0314 - accuracy: 0.9895 - val_loss: 0.5373 - val_accuracy: 0.9161
# Epoch 101/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0369 - accuracy: 0.9880 - val_loss: 0.3490 - val_accuracy: 0.9161
# Epoch 102/250
# 1326/1326 [==============================] - 34s 26ms/step - loss: 0.0250 - accuracy: 0.9922 - val_loss: 0.4673 - val_accuracy: 0.9025
# 14/14 [==============================] - 2s 84ms/step - loss: 0.4357 - accuracy: 0.9165
# 14/14 [==============================] - 1s 22ms/step
#               precision    recall  f1-score   support
#
#            0       0.87      0.76      0.81        51
#            1       0.97      1.00      0.99        39
#            2       0.99      0.96      0.97        73
#            3       0.74      0.85      0.79        27
#            4       0.83      0.90      0.86        49
#            5       0.97      0.95      0.96        38
#            6       0.94      0.94      0.94        52
#            7       0.97      0.94      0.95        64
#            8       0.88      0.92      0.90        50
#
#     accuracy                           0.92       443
#    macro avg       0.91      0.91      0.91       443
# weighted avg       0.92      0.92      0.92       443
# 14/14 [==============================] - 0s 23ms/step

# %%
import keras
model.save_weights('/kaggle/working/custom.h5', overwrite=True)

# %%
# !zip -r file.zip /kaggle/working/checkpoint
# Out:
#   adding: kaggle/working/checkpoint (deflated 34%)

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate,Flatten, Dense, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense


# this could also be the output a different Keras model or layer
input_tensor = Input(shape=(224, 224, 3))

base_model = InceptionV3(input_tensor=input_tensor, weights=None,
                    include_top=False )
base_model.trainable = True
x = base_model.output
x=Flatten()(x)
x=Dense(128,activation='relu')(x)
x=Dense(64,activation='relu')(x)
x= Dense(9, activation='softmax')(x)

model2= Model(inputs=input_tensor, outputs=x)

model2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
"""for layer in model.layers:
   layer.trainable = True"""
#model.summary()

model_checkpoint_callback = keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=30,restore_best_weights=True)

history = model2.fit(train_images, train_lables, batch_size=8, epochs=250,

        validation_data=(valid_images, valid_lables), callbacks=[model_checkpoint_callback])

#callbacks = [EarlyStopping(monitor='loss', patience=5)]
test_loss=model2.evaluate(test_images,test_lables)
predictions=model2.predict(test_images)
pred_lables=np.argmax(predictions,axis=1)
print(classification_report(test_lables,pred_lables))

def plot_accuracy_loss(history):
  fig=plt.figure(figsize=(10,5))

  #plot accuarcy
  plt.subplot(221)
  plt.plot(history.history['accuracy'],label='acc')
  plt.plot(history.history['val_accuracy'],label='val_acc')
  plt.title('train_acc vs val_acc')
  plt.ylabel("accuracy")
  plt.xlabel("epochs")
  plt.legend()


  #plot loss
  plt.subplot(222)
  plt.plot(history.history['loss'],label='loss')
  plt.plot(history.history['val_loss'],label='val_loss')
  plt.title('train_loss vs val_loss')
  plt.ylabel("loss")
  plt.xlabel("epochs")
  plt.legend()

  plt.show()

plot_accuracy_loss(history)
# Out:
# Epoch 1/250
#
# 1326/1326 [==============================] - 150s 80ms/step - loss: 1.9508 - accuracy: 0.3017 - val_loss: 1.4661 - val_accuracy: 0.4218
#
# Epoch 2/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 1.5371 - accuracy: 0.3924 - val_loss: 1.4696 - val_accuracy: 0.4195
#
# Epoch 3/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 1.4596 - accuracy: 0.4208 - val_loss: 1.9458 - val_accuracy: 0.3810
#
# Epoch 4/250
#
# 1326/1326 [==============================] - 103s 77ms/step - loss: 1.2851 - accuracy: 0.5055 - val_loss: 0.9718 - val_accuracy: 0.6644
#
# Epoch 5/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 1.1019 - accuracy: 0.5887 - val_loss: 1.1003 - val_accuracy: 0.6009
#
# Epoch 6/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.9796 - accuracy: 0.6362 - val_loss: 1.5860 - val_accuracy: 0.5057
#
# Epoch 7/250
#
# 1326/1326 [==============================] - 103s 77ms/step - loss: 0.9159 - accuracy: 0.6650 - val_loss: 0.6929 - val_accuracy: 0.7778
#
# Epoch 8/250
#
# 1326/1326 [==============================] - 103s 77ms/step - loss: 0.8482 - accuracy: 0.6999 - val_loss: 0.8914 - val_accuracy: 0.6712
#
# Epoch 9/250
#
# 1326/1326 [==============================] - 103s 78ms/step - loss: 0.7951 - accuracy: 0.7288 - val_loss: 0.6462 - val_accuracy: 0.8095
#
# Epoch 10/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.6688 - accuracy: 0.7677 - val_loss: 0.8140 - val_accuracy: 0.7755
#
# Epoch 11/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.6203 - accuracy: 0.7889 - val_loss: 0.8045 - val_accuracy: 0.7959
#
# Epoch 12/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.5788 - accuracy: 0.8005 - val_loss: 0.7169 - val_accuracy: 0.7755
#
# Epoch 13/250
#
# 1326/1326 [==============================] - 103s 77ms/step - loss: 0.5343 - accuracy: 0.8150 - val_loss: 0.5482 - val_accuracy: 0.8299
#
# Epoch 14/250
#
# 1326/1326 [==============================] - 103s 77ms/step - loss: 0.4987 - accuracy: 0.8311 - val_loss: 0.4704 - val_accuracy: 0.8662
#
# Epoch 15/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.4605 - accuracy: 0.8421 - val_loss: 0.5856 - val_accuracy: 0.8073
#
# Epoch 16/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.4410 - accuracy: 0.8540 - val_loss: 0.6043 - val_accuracy: 0.8073
#
# Epoch 17/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.4527 - accuracy: 0.8429 - val_loss: 0.4715 - val_accuracy: 0.8526
#
# Epoch 18/250
#
# 1326/1326 [==============================] - 103s 78ms/step - loss: 0.3827 - accuracy: 0.8722 - val_loss: 0.4504 - val_accuracy: 0.8503
#
# Epoch 19/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.3632 - accuracy: 0.8812 - val_loss: 0.4527 - val_accuracy: 0.8458
#
# Epoch 20/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.3482 - accuracy: 0.8839 - val_loss: 0.5094 - val_accuracy: 0.8299
#
# Epoch 21/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.3165 - accuracy: 0.8932 - val_loss: 0.5259 - val_accuracy: 0.8730
#
# Epoch 22/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.3101 - accuracy: 0.8973 - val_loss: 0.5246 - val_accuracy: 0.8209
#
# Epoch 23/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.2947 - accuracy: 0.9019 - val_loss: 0.3938 - val_accuracy: 0.8866
#
# Epoch 24/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.2597 - accuracy: 0.9122 - val_loss: 0.8237 - val_accuracy: 0.8390
#
# Epoch 25/250
#
# 1326/1326 [==============================] - 103s 77ms/step - loss: 0.2434 - accuracy: 0.9169 - val_loss: 0.4576 - val_accuracy: 0.8730
#
# Epoch 26/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.2343 - accuracy: 0.9210 - val_loss: 0.8782 - val_accuracy: 0.8798
#
# Epoch 27/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.2187 - accuracy: 0.9237 - val_loss: 0.7379 - val_accuracy: 0.8889
#
# Epoch 28/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.2080 - accuracy: 0.9259 - val_loss: 0.5246 - val_accuracy: 0.8685
#
# Epoch 29/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.1979 - accuracy: 0.9320 - val_loss: 1.9283 - val_accuracy: 0.8594
#
# Epoch 30/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.1983 - accuracy: 0.9349 - val_loss: 1.3912 - val_accuracy: 0.8889
#
# Epoch 31/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.1731 - accuracy: 0.9402 - val_loss: 0.8743 - val_accuracy: 0.8980
#
# Epoch 32/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.1651 - accuracy: 0.9450 - val_loss: 0.3000 - val_accuracy: 0.9048
#
# Epoch 33/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.1488 - accuracy: 0.9490 - val_loss: 0.3548 - val_accuracy: 0.8934
#
# Epoch 34/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.1516 - accuracy: 0.9482 - val_loss: 0.3258 - val_accuracy: 0.8912
#
# Epoch 35/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.1329 - accuracy: 0.9523 - val_loss: 3.2206 - val_accuracy: 0.8118
#
# Epoch 36/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.1442 - accuracy: 0.9514 - val_loss: 0.9079 - val_accuracy: 0.8730
#
# Epoch 37/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.1280 - accuracy: 0.9576 - val_loss: 1.0839 - val_accuracy: 0.8753
#
# Epoch 38/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.1235 - accuracy: 0.9585 - val_loss: 0.8784 - val_accuracy: 0.8866
#
# Epoch 39/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.1152 - accuracy: 0.9609 - val_loss: 5.5959 - val_accuracy: 0.8118
#
# Epoch 40/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.1158 - accuracy: 0.9618 - val_loss: 1.1992 - val_accuracy: 0.8685
#
# Epoch 41/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.1255 - accuracy: 0.9598 - val_loss: 0.3872 - val_accuracy: 0.9048
#
# Epoch 42/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.0973 - accuracy: 0.9679 - val_loss: 0.6055 - val_accuracy: 0.9002
#
# Epoch 43/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.1009 - accuracy: 0.9654 - val_loss: 0.6615 - val_accuracy: 0.8753
#
# Epoch 44/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.1073 - accuracy: 0.9677 - val_loss: 0.4652 - val_accuracy: 0.8957
#
# Epoch 45/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.1732 - accuracy: 0.9453 - val_loss: 0.4854 - val_accuracy: 0.8889
#
# Epoch 46/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.0961 - accuracy: 0.9691 - val_loss: 0.5764 - val_accuracy: 0.8980
#
# Epoch 47/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.0819 - accuracy: 0.9749 - val_loss: 0.7755 - val_accuracy: 0.8844
#
# Epoch 48/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.0897 - accuracy: 0.9732 - val_loss: 0.9414 - val_accuracy: 0.8413
#
# Epoch 49/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.0957 - accuracy: 0.9718 - val_loss: 0.4825 - val_accuracy: 0.9025
#
# Epoch 50/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.0792 - accuracy: 0.9756 - val_loss: 0.6200 - val_accuracy: 0.9048
#
# Epoch 51/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.0753 - accuracy: 0.9755 - val_loss: 0.5517 - val_accuracy: 0.9025
#
# Epoch 52/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.1050 - accuracy: 0.9669 - val_loss: 0.4883 - val_accuracy: 0.9025
#
# Epoch 53/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.0816 - accuracy: 0.9753 - val_loss: 0.6456 - val_accuracy: 0.8798
#
# Epoch 54/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.0754 - accuracy: 0.9753 - val_loss: 0.5430 - val_accuracy: 0.9048
#
# Epoch 55/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.0736 - accuracy: 0.9763 - val_loss: 0.8109 - val_accuracy: 0.8753
#
# Epoch 56/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.0748 - accuracy: 0.9768 - val_loss: 1.4437 - val_accuracy: 0.8934
#
# Epoch 57/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.0714 - accuracy: 0.9787 - val_loss: 1.5955 - val_accuracy: 0.8639
#
# Epoch 58/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.0622 - accuracy: 0.9806 - val_loss: 2.1687 - val_accuracy: 0.8345
#
# Epoch 59/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.0573 - accuracy: 0.9818 - val_loss: 1.0816 - val_accuracy: 0.8730
#
# Epoch 60/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.0673 - accuracy: 0.9794 - val_loss: 0.5046 - val_accuracy: 0.8934
#
# Epoch 61/250
#
# 1326/1326 [==============================] - 103s 77ms/step - loss: 0.0755 - accuracy: 0.9772 - val_loss: 0.7740 - val_accuracy: 0.8662
#
# Epoch 62/250
#
# 1326/1326 [==============================] - 102s 77ms/step - loss: 0.0554 - accuracy: 0.9833 - val_loss: 2.0998 - val_accuracy: 0.8481
#
# 14/14 [==============================] - 4s 194ms/step - loss: 0.3810 - accuracy: 0.9007
#
# 14/14 [==============================] - 2s 69ms/step
#
#               precision    recall  f1-score   support
#
#
#
#            0       0.82      0.73      0.77        51
#
#            1       0.97      0.97      0.97        39
#
#            2       0.96      0.93      0.94        73
#
#            3       0.73      0.81      0.77        27
#
#            4       0.82      0.94      0.88        49
#
#            5       0.88      0.95      0.91        38
#
#            6       0.98      0.92      0.95        52
#
#            7       0.93      0.89      0.91        64
#
#            8       0.92      0.94      0.93        50
#
#
#
#     accuracy                           0.90       443
#
#    macro avg       0.89      0.90      0.89       443
#
# weighted avg       0.90      0.90      0.90       443

# %%
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate,Flatten, Dense, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense


# this could also be the output a different Keras model or layer
input_tensor = Input(shape=(224, 224, 3))

base_model = ResNet50V2(input_tensor=input_tensor, weights='imagenet',
                    include_top=False )

x = base_model.output
x=Flatten()(x)
x=Dense(128,activation='relu')(x)
x=Dense(64,activation='relu')(x)
x= Dense(9, activation='softmax')(x)

model= Model(inputs=input_tensor, outputs=x)

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
for layer in model.layers:
   layer.trainable = True
model.summary()

model_checkpoint_callback = keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=30,restore_best_weights=True)

history = model.fit(train_images, train_lables, batch_size=8, epochs=250,

        validation_data=(valid_images, valid_lables), callbacks=[model_checkpoint_callback])
#callbacks = [EarlyStopping(monitor='loss', patience=5)]

test_loss=model.evaluate(test_images,test_lables)
predictions=model.predict(test_images)
pred_lables=np.argmax(predictions,axis=1)
print(classification_report(test_lables,pred_lables))

def plot_accuracy_loss(history):
  fig=plt.figure(figsize=(10,5))

  #plot accuarcy
  plt.subplot(221)
  plt.plot(history.history['accuracy'],label='acc')
  plt.plot(history.history['val_accuracy'],label='val_acc')
  plt.title('train_acc vs val_acc')
  plt.ylabel("accuracy")
  plt.xlabel("epochs")
  plt.legend()


  #plot loss
  plt.subplot(222)
  plt.plot(history.history['loss'],label='loss')
  plt.plot(history.history['val_loss'],label='val_loss')
  plt.title('train_loss vs val_loss')
  plt.ylabel("loss")
  plt.xlabel("epochs")
  plt.legend()

  plt.show()

plot_accuracy_loss(history)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
#
# 94668760/94668760 [==============================] - 1s 0us/step
#
# Model: "model"
#
# __________________________________________________________________________________________________
#
#  Layer (type)                Output Shape                 Param #   Connected to
#
# ==================================================================================================
#
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#
#
#  conv1_pad (ZeroPadding2D)   (None, 230, 230, 3)          0         ['input_1[0][0]']
#
#
#
#  conv1_conv (Conv2D)         (None, 112, 112, 64)         9472      ['conv1_pad[0][0]']
#
#
#
#  pool1_pad (ZeroPadding2D)   (None, 114, 114, 64)         0         ['conv1_conv[0][0]']
#
#
#
#  pool1_pool (MaxPooling2D)   (None, 56, 56, 64)           0         ['pool1_pad[0][0]']
#
#
#
#  conv2_block1_preact_bn (Ba  (None, 56, 56, 64)           256       ['pool1_pool[0][0]']
#
#  tchNormalization)
#
#
#
#  conv2_block1_preact_relu (  (None, 56, 56, 64)           0         ['conv2_block1_preact_bn[0][0]
#
#  Activation)                                                        ']
#
#
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 64)           4096      ['conv2_block1_preact_relu[0][
#
#  D)                                                                 0]']
#
#
#
#  conv2_block1_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_1_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv2_block1_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_1_bn[0][0]']
#
#  ation)
#
#
#
#  conv2_block1_2_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block1_1_relu[0][0]']
#
#  dding2D)
#
#
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block1_2_pad[0][0]']
#
#  D)
#
#
#
#  conv2_block1_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_2_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv2_block1_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_2_bn[0][0]']
#
#  ation)
#
#
#
#  conv2_block1_0_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block1_preact_relu[0][
#
#  D)                                                                 0]']
#
#
#
#  conv2_block1_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block1_2_relu[0][0]']
#
#  D)
#
#
#
#  conv2_block1_out (Add)      (None, 56, 56, 256)          0         ['conv2_block1_0_conv[0][0]',
#
#                                                                      'conv2_block1_3_conv[0][0]']
#
#
#
#  conv2_block2_preact_bn (Ba  (None, 56, 56, 256)          1024      ['conv2_block1_out[0][0]']
#
#  tchNormalization)
#
#
#
#  conv2_block2_preact_relu (  (None, 56, 56, 256)          0         ['conv2_block2_preact_bn[0][0]
#
#  Activation)                                                        ']
#
#
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 64)           16384     ['conv2_block2_preact_relu[0][
#
#  D)                                                                 0]']
#
#
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_1_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv2_block2_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block2_1_bn[0][0]']
#
#  ation)
#
#
#
#  conv2_block2_2_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block2_1_relu[0][0]']
#
#  dding2D)
#
#
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block2_2_pad[0][0]']
#
#  D)
#
#
#
#  conv2_block2_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_2_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv2_block2_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block2_2_bn[0][0]']
#
#  ation)
#
#
#
#  conv2_block2_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block2_2_relu[0][0]']
#
#  D)
#
#
#
#  conv2_block2_out (Add)      (None, 56, 56, 256)          0         ['conv2_block1_out[0][0]',
#
#                                                                      'conv2_block2_3_conv[0][0]']
#
#
#
#  conv2_block3_preact_bn (Ba  (None, 56, 56, 256)          1024      ['conv2_block2_out[0][0]']
#
#  tchNormalization)
#
#
#
#  conv2_block3_preact_relu (  (None, 56, 56, 256)          0         ['conv2_block3_preact_bn[0][0]
#
#  Activation)                                                        ']
#
#
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 64)           16384     ['conv2_block3_preact_relu[0][
#
#  D)                                                                 0]']
#
#
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_1_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv2_block3_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block3_1_bn[0][0]']
#
#  ation)
#
#
#
#  conv2_block3_2_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block3_1_relu[0][0]']
#
#  dding2D)
#
#
#
#  conv2_block3_2_conv (Conv2  (None, 28, 28, 64)           36864     ['conv2_block3_2_pad[0][0]']
#
#  D)
#
#
#
#  conv2_block3_2_bn (BatchNo  (None, 28, 28, 64)           256       ['conv2_block3_2_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv2_block3_2_relu (Activ  (None, 28, 28, 64)           0         ['conv2_block3_2_bn[0][0]']
#
#  ation)
#
#
#
#  max_pooling2d_3 (MaxPoolin  (None, 28, 28, 256)          0         ['conv2_block2_out[0][0]']
#
#  g2D)
#
#
#
#  conv2_block3_3_conv (Conv2  (None, 28, 28, 256)          16640     ['conv2_block3_2_relu[0][0]']
#
#  D)
#
#
#
#  conv2_block3_out (Add)      (None, 28, 28, 256)          0         ['max_pooling2d_3[0][0]',
#
#                                                                      'conv2_block3_3_conv[0][0]']
#
#
#
#  conv3_block1_preact_bn (Ba  (None, 28, 28, 256)          1024      ['conv2_block3_out[0][0]']
#
#  tchNormalization)
#
#
#
#  conv3_block1_preact_relu (  (None, 28, 28, 256)          0         ['conv3_block1_preact_bn[0][0]
#
#  Activation)                                                        ']
#
#
#
#  conv3_block1_1_conv (Conv2  (None, 28, 28, 128)          32768     ['conv3_block1_preact_relu[0][
#
#  D)                                                                 0]']
#
#
#
#  conv3_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_1_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv3_block1_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_1_bn[0][0]']
#
#  ation)
#
#
#
#  conv3_block1_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block1_1_relu[0][0]']
#
#  dding2D)
#
#
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block1_2_pad[0][0]']
#
#  D)
#
#
#
#  conv3_block1_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_2_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv3_block1_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_2_bn[0][0]']
#
#  ation)
#
#
#
#  conv3_block1_0_conv (Conv2  (None, 28, 28, 512)          131584    ['conv3_block1_preact_relu[0][
#
#  D)                                                                 0]']
#
#
#
#  conv3_block1_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block1_2_relu[0][0]']
#
#  D)
#
#
#
#  conv3_block1_out (Add)      (None, 28, 28, 512)          0         ['conv3_block1_0_conv[0][0]',
#
#                                                                      'conv3_block1_3_conv[0][0]']
#
#
#
#  conv3_block2_preact_bn (Ba  (None, 28, 28, 512)          2048      ['conv3_block1_out[0][0]']
#
#  tchNormalization)
#
#
#
#  conv3_block2_preact_relu (  (None, 28, 28, 512)          0         ['conv3_block2_preact_bn[0][0]
#
#  Activation)                                                        ']
#
#
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          65536     ['conv3_block2_preact_relu[0][
#
#  D)                                                                 0]']
#
#
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv3_block2_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_1_bn[0][0]']
#
#  ation)
#
#
#
#  conv3_block2_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block2_1_relu[0][0]']
#
#  dding2D)
#
#
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block2_2_pad[0][0]']
#
#  D)
#
#
#
#  conv3_block2_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_2_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv3_block2_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_2_bn[0][0]']
#
#  ation)
#
#
#
#  conv3_block2_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block2_2_relu[0][0]']
#
#  D)
#
#
#
#  conv3_block2_out (Add)      (None, 28, 28, 512)          0         ['conv3_block1_out[0][0]',
#
#                                                                      'conv3_block2_3_conv[0][0]']
#
#
#
#  conv3_block3_preact_bn (Ba  (None, 28, 28, 512)          2048      ['conv3_block2_out[0][0]']
#
#  tchNormalization)
#
#
#
#  conv3_block3_preact_relu (  (None, 28, 28, 512)          0         ['conv3_block3_preact_bn[0][0]
#
#  Activation)                                                        ']
#
#
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          65536     ['conv3_block3_preact_relu[0][
#
#  D)                                                                 0]']
#
#
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv3_block3_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_1_bn[0][0]']
#
#  ation)
#
#
#
#  conv3_block3_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block3_1_relu[0][0]']
#
#  dding2D)
#
#
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block3_2_pad[0][0]']
#
#  D)
#
#
#
#  conv3_block3_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_2_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv3_block3_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_2_bn[0][0]']
#
#  ation)
#
#
#
#  conv3_block3_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block3_2_relu[0][0]']
#
#  D)
#
#
#
#  conv3_block3_out (Add)      (None, 28, 28, 512)          0         ['conv3_block2_out[0][0]',
#
#                                                                      'conv3_block3_3_conv[0][0]']
#
#
#
#  conv3_block4_preact_bn (Ba  (None, 28, 28, 512)          2048      ['conv3_block3_out[0][0]']
#
#  tchNormalization)
#
#
#
#  conv3_block4_preact_relu (  (None, 28, 28, 512)          0         ['conv3_block4_preact_bn[0][0]
#
#  Activation)                                                        ']
#
#
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          65536     ['conv3_block4_preact_relu[0][
#
#  D)                                                                 0]']
#
#
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv3_block4_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_1_bn[0][0]']
#
#  ation)
#
#
#
#  conv3_block4_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block4_1_relu[0][0]']
#
#  dding2D)
#
#
#
#  conv3_block4_2_conv (Conv2  (None, 14, 14, 128)          147456    ['conv3_block4_2_pad[0][0]']
#
#  D)
#
#
#
#  conv3_block4_2_bn (BatchNo  (None, 14, 14, 128)          512       ['conv3_block4_2_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv3_block4_2_relu (Activ  (None, 14, 14, 128)          0         ['conv3_block4_2_bn[0][0]']
#
#  ation)
#
#
#
#  max_pooling2d_4 (MaxPoolin  (None, 14, 14, 512)          0         ['conv3_block3_out[0][0]']
#
#  g2D)
#
#
#
#  conv3_block4_3_conv (Conv2  (None, 14, 14, 512)          66048     ['conv3_block4_2_relu[0][0]']
#
#  D)
#
#
#
#  conv3_block4_out (Add)      (None, 14, 14, 512)          0         ['max_pooling2d_4[0][0]',
#
#                                                                      'conv3_block4_3_conv[0][0]']
#
#
#
#  conv4_block1_preact_bn (Ba  (None, 14, 14, 512)          2048      ['conv3_block4_out[0][0]']
#
#  tchNormalization)
#
#
#
#  conv4_block1_preact_relu (  (None, 14, 14, 512)          0         ['conv4_block1_preact_bn[0][0]
#
#  Activation)                                                        ']
#
#
#
#  conv4_block1_1_conv (Conv2  (None, 14, 14, 256)          131072    ['conv4_block1_preact_relu[0][
#
#  D)                                                                 0]']
#
#
#
#  conv4_block1_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_1_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv4_block1_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_1_bn[0][0]']
#
#  ation)
#
#
#
#  conv4_block1_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block1_1_relu[0][0]']
#
#  dding2D)
#
#
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block1_2_pad[0][0]']
#
#  D)
#
#
#
#  conv4_block1_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_2_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv4_block1_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_2_bn[0][0]']
#
#  ation)
#
#
#
#  conv4_block1_0_conv (Conv2  (None, 14, 14, 1024)         525312    ['conv4_block1_preact_relu[0][
#
#  D)                                                                 0]']
#
#
#
#  conv4_block1_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#
#  D)
#
#
#
#  conv4_block1_out (Add)      (None, 14, 14, 1024)         0         ['conv4_block1_0_conv[0][0]',
#
#                                                                      'conv4_block1_3_conv[0][0]']
#
#
#
#  conv4_block2_preact_bn (Ba  (None, 14, 14, 1024)         4096      ['conv4_block1_out[0][0]']
#
#  tchNormalization)
#
#
#
#  conv4_block2_preact_relu (  (None, 14, 14, 1024)         0         ['conv4_block2_preact_bn[0][0]
#
#  Activation)                                                        ']
#
#
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 256)          262144    ['conv4_block2_preact_relu[0][
#
#  D)                                                                 0]']
#
#
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_1_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv4_block2_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block2_1_bn[0][0]']
#
#  ation)
#
#
#
#  conv4_block2_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block2_1_relu[0][0]']
#
#  dding2D)
#
#
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block2_2_pad[0][0]']
#
#  D)
#
#
#
#  conv4_block2_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_2_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv4_block2_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block2_2_bn[0][0]']
#
#  ation)
#
#
#
#  conv4_block2_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#
#  D)
#
#
#
#  conv4_block2_out (Add)      (None, 14, 14, 1024)         0         ['conv4_block1_out[0][0]',
#
#                                                                      'conv4_block2_3_conv[0][0]']
#
#
#
#  conv4_block3_preact_bn (Ba  (None, 14, 14, 1024)         4096      ['conv4_block2_out[0][0]']
#
#  tchNormalization)
#
#
#
#  conv4_block3_preact_relu (  (None, 14, 14, 1024)         0         ['conv4_block3_preact_bn[0][0]
#
#  Activation)                                                        ']
#
#
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 256)          262144    ['conv4_block3_preact_relu[0][
#
#  D)                                                                 0]']
#
#
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_1_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv4_block3_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block3_1_bn[0][0]']
#
#  ation)
#
#
#
#  conv4_block3_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block3_1_relu[0][0]']
#
#  dding2D)
#
#
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block3_2_pad[0][0]']
#
#  D)
#
#
#
#  conv4_block3_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_2_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv4_block3_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block3_2_bn[0][0]']
#
#  ation)
#
#
#
#  conv4_block3_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#
#  D)
#
#
#
#  conv4_block3_out (Add)      (None, 14, 14, 1024)         0         ['conv4_block2_out[0][0]',
#
#                                                                      'conv4_block3_3_conv[0][0]']
#
#
#
#  conv4_block4_preact_bn (Ba  (None, 14, 14, 1024)         4096      ['conv4_block3_out[0][0]']
#
#  tchNormalization)
#
#
#
#  conv4_block4_preact_relu (  (None, 14, 14, 1024)         0         ['conv4_block4_preact_bn[0][0]
#
#  Activation)                                                        ']
#
#
#
#  conv4_block4_1_conv (Conv2  (None, 14, 14, 256)          262144    ['conv4_block4_preact_relu[0][
#
#  D)                                                                 0]']
#
#
#
#  conv4_block4_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_1_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv4_block4_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block4_1_bn[0][0]']
#
#  ation)
#
#
#
#  conv4_block4_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block4_1_relu[0][0]']
#
#  dding2D)
#
#
#
#  conv4_block4_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block4_2_pad[0][0]']
#
#  D)
#
#
#
#  conv4_block4_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_2_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv4_block4_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block4_2_bn[0][0]']
#
#  ation)
#
#
#
#  conv4_block4_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#
#  D)
#
#
#
#  conv4_block4_out (Add)      (None, 14, 14, 1024)         0         ['conv4_block3_out[0][0]',
#
#                                                                      'conv4_block4_3_conv[0][0]']
#
#
#
#  conv4_block5_preact_bn (Ba  (None, 14, 14, 1024)         4096      ['conv4_block4_out[0][0]']
#
#  tchNormalization)
#
#
#
#  conv4_block5_preact_relu (  (None, 14, 14, 1024)         0         ['conv4_block5_preact_bn[0][0]
#
#  Activation)                                                        ']
#
#
#
#  conv4_block5_1_conv (Conv2  (None, 14, 14, 256)          262144    ['conv4_block5_preact_relu[0][
#
#  D)                                                                 0]']
#
#
#
#  conv4_block5_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_1_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv4_block5_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block5_1_bn[0][0]']
#
#  ation)
#
#
#
#  conv4_block5_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block5_1_relu[0][0]']
#
#  dding2D)
#
#
#
#  conv4_block5_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block5_2_pad[0][0]']
#
#  D)
#
#
#
#  conv4_block5_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_2_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv4_block5_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block5_2_bn[0][0]']
#
#  ation)
#
#
#
#  conv4_block5_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block5_2_relu[0][0]']
#
#  D)
#
#
#
#  conv4_block5_out (Add)      (None, 14, 14, 1024)         0         ['conv4_block4_out[0][0]',
#
#                                                                      'conv4_block5_3_conv[0][0]']
#
#
#
#  conv4_block6_preact_bn (Ba  (None, 14, 14, 1024)         4096      ['conv4_block5_out[0][0]']
#
#  tchNormalization)
#
#
#
#  conv4_block6_preact_relu (  (None, 14, 14, 1024)         0         ['conv4_block6_preact_bn[0][0]
#
#  Activation)                                                        ']
#
#
#
#  conv4_block6_1_conv (Conv2  (None, 14, 14, 256)          262144    ['conv4_block6_preact_relu[0][
#
#  D)                                                                 0]']
#
#
#
#  conv4_block6_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_1_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv4_block6_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block6_1_bn[0][0]']
#
#  ation)
#
#
#
#  conv4_block6_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block6_1_relu[0][0]']
#
#  dding2D)
#
#
#
#  conv4_block6_2_conv (Conv2  (None, 7, 7, 256)            589824    ['conv4_block6_2_pad[0][0]']
#
#  D)
#
#
#
#  conv4_block6_2_bn (BatchNo  (None, 7, 7, 256)            1024      ['conv4_block6_2_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv4_block6_2_relu (Activ  (None, 7, 7, 256)            0         ['conv4_block6_2_bn[0][0]']
#
#  ation)
#
#
#
#  max_pooling2d_5 (MaxPoolin  (None, 7, 7, 1024)           0         ['conv4_block5_out[0][0]']
#
#  g2D)
#
#
#
#  conv4_block6_3_conv (Conv2  (None, 7, 7, 1024)           263168    ['conv4_block6_2_relu[0][0]']
#
#  D)
#
#
#
#  conv4_block6_out (Add)      (None, 7, 7, 1024)           0         ['max_pooling2d_5[0][0]',
#
#                                                                      'conv4_block6_3_conv[0][0]']
#
#
#
#  conv5_block1_preact_bn (Ba  (None, 7, 7, 1024)           4096      ['conv4_block6_out[0][0]']
#
#  tchNormalization)
#
#
#
#  conv5_block1_preact_relu (  (None, 7, 7, 1024)           0         ['conv5_block1_preact_bn[0][0]
#
#  Activation)                                                        ']
#
#
#
#  conv5_block1_1_conv (Conv2  (None, 7, 7, 512)            524288    ['conv5_block1_preact_relu[0][
#
#  D)                                                                 0]']
#
#
#
#  conv5_block1_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_1_conv[0][0]']
#
#  rmalization)
#
#
#
#  conv5_block1_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block1_1_bn[0][0]']
#
#  ation)
#
#
#
#  conv5_block1_2_pad (ZeroPa  (None, 9, 9, 512)            0         ['conv5_block1_1_relu[0][0]']
#
#  dding2D)
#
# ...
#
# Epoch 6/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 1.0943 - accuracy: 0.5438 - val_loss: 1.2519 - val_accuracy: 0.5782
#
# Epoch 7/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.9898 - accuracy: 0.6047 - val_loss: 0.9247 - val_accuracy: 0.6372
#
# Epoch 8/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.8559 - accuracy: 0.6737 - val_loss: 0.9893 - val_accuracy: 0.6825
#
# Epoch 9/250
#
# 1326/1326 [==============================] - 120s 91ms/step - loss: 0.7204 - accuracy: 0.7378 - val_loss: 0.8139 - val_accuracy: 0.7279
#
# Epoch 10/250
#
# 1326/1326 [==============================] - 120s 91ms/step - loss: 0.5760 - accuracy: 0.7875 - val_loss: 0.7756 - val_accuracy: 0.7732
#
# Epoch 11/250
#
# 1326/1326 [==============================] - 120s 91ms/step - loss: 0.4664 - accuracy: 0.8354 - val_loss: 0.9217 - val_accuracy: 0.7324
#
# Epoch 12/250
#
# 1326/1326 [==============================] - 120s 91ms/step - loss: 0.3948 - accuracy: 0.8616 - val_loss: 0.8937 - val_accuracy: 0.7483
#
# Epoch 13/250
#
# 1326/1326 [==============================] - 120s 91ms/step - loss: 0.3291 - accuracy: 0.8885 - val_loss: 0.6427 - val_accuracy: 0.8163
#
# Epoch 14/250
#
# 1326/1326 [==============================] - 120s 91ms/step - loss: 0.2861 - accuracy: 0.9031 - val_loss: 0.9010 - val_accuracy: 0.7710
#
# Epoch 15/250
#
# 1326/1326 [==============================] - 120s 91ms/step - loss: 0.2241 - accuracy: 0.9261 - val_loss: 0.6034 - val_accuracy: 0.8707
#
# Epoch 16/250
#
# 1326/1326 [==============================] - 120s 91ms/step - loss: 0.1865 - accuracy: 0.9384 - val_loss: 0.7379 - val_accuracy: 0.8413
#
# Epoch 17/250
#
# 1326/1326 [==============================] - 120s 91ms/step - loss: 0.1779 - accuracy: 0.9406 - val_loss: 0.6508 - val_accuracy: 0.8481
#
# Epoch 18/250
#
# 1326/1326 [==============================] - 120s 91ms/step - loss: 0.1388 - accuracy: 0.9523 - val_loss: 0.8248 - val_accuracy: 0.8413
#
# Epoch 19/250
#
# 1326/1326 [==============================] - 120s 90ms/step - loss: 0.1500 - accuracy: 0.9550 - val_loss: 0.7850 - val_accuracy: 0.8345
#
# Epoch 20/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.1132 - accuracy: 0.9652 - val_loss: 2.6372 - val_accuracy: 0.6531
#
# Epoch 21/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.1215 - accuracy: 0.9626 - val_loss: 0.9244 - val_accuracy: 0.8027
#
# Epoch 22/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.1107 - accuracy: 0.9646 - val_loss: 1.6869 - val_accuracy: 0.7687
#
# Epoch 23/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0976 - accuracy: 0.9711 - val_loss: 0.8296 - val_accuracy: 0.8435
#
# Epoch 24/250
#
# 1326/1326 [==============================] - 120s 90ms/step - loss: 0.0927 - accuracy: 0.9727 - val_loss: 0.6352 - val_accuracy: 0.8821
#
# Epoch 25/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0902 - accuracy: 0.9724 - val_loss: 0.9798 - val_accuracy: 0.8005
#
# Epoch 26/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0767 - accuracy: 0.9762 - val_loss: 0.6355 - val_accuracy: 0.8730
#
# Epoch 27/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0785 - accuracy: 0.9779 - val_loss: 1.1894 - val_accuracy: 0.8322
#
# Epoch 28/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0711 - accuracy: 0.9789 - val_loss: 1.3352 - val_accuracy: 0.7619
#
# Epoch 29/250
#
# 1326/1326 [==============================] - 120s 91ms/step - loss: 0.0868 - accuracy: 0.9748 - val_loss: 0.7086 - val_accuracy: 0.8753
#
# Epoch 30/250
#
# 1326/1326 [==============================] - 120s 91ms/step - loss: 0.0727 - accuracy: 0.9799 - val_loss: 0.7352 - val_accuracy: 0.8798
#
# Epoch 31/250
#
# 1326/1326 [==============================] - 120s 91ms/step - loss: 0.0598 - accuracy: 0.9803 - val_loss: 0.5857 - val_accuracy: 0.8776
#
# Epoch 32/250
#
# 1326/1326 [==============================] - 120s 91ms/step - loss: 0.0609 - accuracy: 0.9827 - val_loss: 1.4822 - val_accuracy: 0.7460
#
# Epoch 33/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0602 - accuracy: 0.9826 - val_loss: 0.7492 - val_accuracy: 0.8753
#
# Epoch 34/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0623 - accuracy: 0.9819 - val_loss: 0.8782 - val_accuracy: 0.8662
#
# Epoch 35/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0650 - accuracy: 0.9821 - val_loss: 0.7828 - val_accuracy: 0.8571
#
# Epoch 36/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0501 - accuracy: 0.9862 - val_loss: 1.1286 - val_accuracy: 0.8095
#
# Epoch 37/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0421 - accuracy: 0.9880 - val_loss: 0.8983 - val_accuracy: 0.8798
#
# Epoch 38/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0501 - accuracy: 0.9851 - val_loss: 3.0946 - val_accuracy: 0.5760
#
# Epoch 39/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0652 - accuracy: 0.9827 - val_loss: 0.8493 - val_accuracy: 0.8571
#
# Epoch 40/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0654 - accuracy: 0.9845 - val_loss: 0.7833 - val_accuracy: 0.8753
#
# Epoch 41/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0449 - accuracy: 0.9877 - val_loss: 0.6881 - val_accuracy: 0.8617
#
# Epoch 42/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0450 - accuracy: 0.9862 - val_loss: 0.7084 - val_accuracy: 0.8934
#
# Epoch 43/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0466 - accuracy: 0.9880 - val_loss: 0.9312 - val_accuracy: 0.8571
#
# Epoch 44/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0397 - accuracy: 0.9893 - val_loss: 0.7591 - val_accuracy: 0.8866
#
# Epoch 45/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0519 - accuracy: 0.9848 - val_loss: 0.9334 - val_accuracy: 0.8753
#
# Epoch 46/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0484 - accuracy: 0.9877 - val_loss: 0.9682 - val_accuracy: 0.8594
#
# Epoch 47/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0440 - accuracy: 0.9883 - val_loss: 1.0768 - val_accuracy: 0.8209
#
# Epoch 48/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0455 - accuracy: 0.9879 - val_loss: 0.7050 - val_accuracy: 0.8957
#
# Epoch 49/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0413 - accuracy: 0.9901 - val_loss: 1.0036 - val_accuracy: 0.8526
#
# Epoch 50/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0391 - accuracy: 0.9893 - val_loss: 1.0330 - val_accuracy: 0.8798
#
# Epoch 51/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0435 - accuracy: 0.9872 - val_loss: 0.8849 - val_accuracy: 0.8798
#
# Epoch 52/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0427 - accuracy: 0.9902 - val_loss: 2.0636 - val_accuracy: 0.7438
#
# Epoch 53/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0550 - accuracy: 0.9865 - val_loss: 1.3921 - val_accuracy: 0.8481
#
# Epoch 54/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0402 - accuracy: 0.9911 - val_loss: 0.9942 - val_accuracy: 0.8821
#
# Epoch 55/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0418 - accuracy: 0.9903 - val_loss: 0.8864 - val_accuracy: 0.8776
#
# Epoch 56/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0310 - accuracy: 0.9924 - val_loss: 0.9608 - val_accuracy: 0.8617
#
# Epoch 57/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0407 - accuracy: 0.9905 - val_loss: 1.1855 - val_accuracy: 0.8617
#
# Epoch 58/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0367 - accuracy: 0.9915 - val_loss: 1.8996 - val_accuracy: 0.8050
#
# Epoch 59/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0476 - accuracy: 0.9880 - val_loss: 1.5214 - val_accuracy: 0.8141
#
# Epoch 60/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0268 - accuracy: 0.9921 - val_loss: 0.9857 - val_accuracy: 0.8707
#
# Epoch 61/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0399 - accuracy: 0.9900 - val_loss: 0.7128 - val_accuracy: 0.8776
#
# Epoch 62/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0276 - accuracy: 0.9933 - val_loss: 0.9398 - val_accuracy: 0.8798
#
# Epoch 63/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0498 - accuracy: 0.9873 - val_loss: 0.9149 - val_accuracy: 0.8753
#
# Epoch 64/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0257 - accuracy: 0.9944 - val_loss: 0.7804 - val_accuracy: 0.8957
#
# Epoch 65/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0377 - accuracy: 0.9910 - val_loss: 0.8427 - val_accuracy: 0.8866
#
# Epoch 66/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0385 - accuracy: 0.9904 - val_loss: 0.9388 - val_accuracy: 0.8594
#
# Epoch 67/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0351 - accuracy: 0.9909 - val_loss: 1.3525 - val_accuracy: 0.8821
#
# Epoch 68/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0354 - accuracy: 0.9921 - val_loss: 0.8096 - val_accuracy: 0.8798
#
# Epoch 69/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0251 - accuracy: 0.9928 - val_loss: 0.8428 - val_accuracy: 0.8753
#
# Epoch 70/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0351 - accuracy: 0.9928 - val_loss: 1.0320 - val_accuracy: 0.8866
#
# Epoch 71/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0203 - accuracy: 0.9950 - val_loss: 1.0051 - val_accuracy: 0.8707
#
# Epoch 72/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0301 - accuracy: 0.9928 - val_loss: 1.2578 - val_accuracy: 0.8571
#
# Epoch 73/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0439 - accuracy: 0.9913 - val_loss: 1.0888 - val_accuracy: 0.8685
#
# Epoch 74/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0308 - accuracy: 0.9927 - val_loss: 1.2778 - val_accuracy: 0.8594
#
# Epoch 75/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0366 - accuracy: 0.9919 - val_loss: 0.8832 - val_accuracy: 0.8617
#
# Epoch 76/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0247 - accuracy: 0.9944 - val_loss: 0.8421 - val_accuracy: 0.9070
#
# Epoch 77/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0179 - accuracy: 0.9939 - val_loss: 1.0282 - val_accuracy: 0.8821
#
# Epoch 78/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0366 - accuracy: 0.9919 - val_loss: 1.3764 - val_accuracy: 0.8639
#
# Epoch 79/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0360 - accuracy: 0.9924 - val_loss: 1.0329 - val_accuracy: 0.8639
#
# Epoch 80/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0493 - accuracy: 0.9912 - val_loss: 0.8802 - val_accuracy: 0.8889
#
# Epoch 81/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0254 - accuracy: 0.9946 - val_loss: 0.8742 - val_accuracy: 0.8866
#
# Epoch 82/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0142 - accuracy: 0.9962 - val_loss: 1.4255 - val_accuracy: 0.8639
#
# Epoch 83/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0439 - accuracy: 0.9925 - val_loss: 1.7886 - val_accuracy: 0.7937
#
# Epoch 84/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0363 - accuracy: 0.9923 - val_loss: 1.2145 - val_accuracy: 0.8844
#
# Epoch 85/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0351 - accuracy: 0.9908 - val_loss: 1.1580 - val_accuracy: 0.8526
#
# Epoch 87/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0178 - accuracy: 0.9953 - val_loss: 0.9448 - val_accuracy: 0.8821
#
# Epoch 88/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0401 - accuracy: 0.9914 - val_loss: 3.6649 - val_accuracy: 0.6190
#
# Epoch 89/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0096 - accuracy: 0.9974 - val_loss: 0.9403 - val_accuracy: 0.8844
#
# Epoch 90/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0258 - accuracy: 0.9946 - val_loss: 1.2521 - val_accuracy: 0.8594
#
# Epoch 91/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0247 - accuracy: 0.9944 - val_loss: 0.8434 - val_accuracy: 0.8912
#
# Epoch 92/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0532 - accuracy: 0.9921 - val_loss: 1.2755 - val_accuracy: 0.8413
#
# Epoch 93/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0201 - accuracy: 0.9947 - val_loss: 1.2961 - val_accuracy: 0.8435
#
# Epoch 94/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0471 - accuracy: 0.9926 - val_loss: 0.8595 - val_accuracy: 0.8934
#
# Epoch 95/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0271 - accuracy: 0.9942 - val_loss: 1.2997 - val_accuracy: 0.8458
#
# Epoch 96/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0163 - accuracy: 0.9955 - val_loss: 0.8776 - val_accuracy: 0.9048
#
# Epoch 97/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0401 - accuracy: 0.9932 - val_loss: 2.9058 - val_accuracy: 0.7347
#
# Epoch 98/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0363 - accuracy: 0.9920 - val_loss: 1.1814 - val_accuracy: 0.8526
#
# Epoch 99/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0093 - accuracy: 0.9978 - val_loss: 1.1071 - val_accuracy: 0.8934
#
# Epoch 100/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0315 - accuracy: 0.9935 - val_loss: 1.6214 - val_accuracy: 0.8322
#
# Epoch 101/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0364 - accuracy: 0.9931 - val_loss: 1.0812 - val_accuracy: 0.8662
#
# Epoch 102/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0085 - accuracy: 0.9977 - val_loss: 1.1502 - val_accuracy: 0.8798
#
# Epoch 103/250
#
# 1326/1326 [==============================] - 119s 89ms/step - loss: 0.0471 - accuracy: 0.9911 - val_loss: 1.0882 - val_accuracy: 0.8844
#
# Epoch 104/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0180 - accuracy: 0.9958 - val_loss: 1.1686 - val_accuracy: 0.8458
#
# Epoch 105/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0320 - accuracy: 0.9938 - val_loss: 1.4192 - val_accuracy: 0.8639
#
# Epoch 106/250
#
# 1326/1326 [==============================] - 119s 90ms/step - loss: 0.0512 - accuracy: 0.9905 - val_loss: 1.1768 - val_accuracy: 0.8481
#
# 14/14 [==============================] - 4s 177ms/step - loss: 0.9323 - accuracy: 0.8781
#
# 14/14 [==============================] - 2s 87ms/step
#
#               precision    recall  f1-score   support
#
#
#
#            0       0.94      0.61      0.74        51
#
#            1       0.93      0.95      0.94        39
#
#            2       0.88      0.90      0.89        73
#
#            3       0.61      0.81      0.70        27
#
#            4       0.88      0.94      0.91        49
#
#            5       0.92      0.92      0.92        38
#
#            6       0.91      0.94      0.92        52
#
#            7       0.94      0.92      0.93        64
#
#            8       0.85      0.88      0.86        50
#
#
#
#     accuracy                           0.88       443
#
#    macro avg       0.87      0.88      0.87       443
#
# weighted avg       0.89      0.88      0.88       443

# %%
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate,Flatten, Dense, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
# Initializing the CNN
model = Sequential()

model.add(Conv2D(96, kernel_size=(11,11), strides= 4,
                      padding= 'valid', activation= 'relu',
                      input_shape= (224,224,3),
                      kernel_initializer= 'he_normal'))
model.add(MaxPooling2D(pool_size=(3,3), strides= (2,2),
                      padding= 'valid', data_format= None))
model.add(BatchNormalization())


model.add(Conv2D(256, kernel_size=(5,5), strides= 1,
                padding= 'same', activation= 'relu',
                kernel_initializer= 'he_normal'))
model.add(MaxPooling2D(pool_size=(3,3), strides= (2,2),
                      padding= 'valid', data_format= None))
model.add(BatchNormalization())
 

model.add(Conv2D(384, kernel_size=(3,3), strides= 1,
                padding= 'same', activation= 'relu',
                kernel_initializer= 'he_normal'))
model.add(BatchNormalization())


model.add(Conv2D(384, kernel_size=(3,3), strides= 1,
                padding= 'same', activation= 'relu',
                kernel_initializer= 'he_normal'))
model.add(BatchNormalization())


model.add(Conv2D(256, kernel_size=(3,3), strides= 1,
                padding= 'same', activation= 'relu',
                kernel_initializer= 'he_normal'))

model.add(MaxPooling2D(pool_size=(3,3), strides= (2,2),
                      padding= 'valid', data_format= None))
model.add(BatchNormalization())



# Flattening Step
model.add(Flatten())

# Full Connection Step
model.add(Dense(units = 4096, activation = 'relu'))
model.add(Dense(units = 4096, activation = 'relu'))
model.add(Dense(units = 9, activation = 'softmax'))
model.summary()

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model_checkpoint_callback = keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=30,restore_best_weights=True)

history = model.fit(train_images, train_lables, batch_size=8, epochs=250,

        validation_data=(valid_images, valid_lables), callbacks=[model_checkpoint_callback])


test_loss=model.evaluate(test_images,test_lables)
predictions=model.predict(test_images)
pred_lables=np.argmax(predictions,axis=1)
print(classification_report(test_lables,pred_lables))

def plot_accuracy_loss(history):
  fig=plt.figure(figsize=(10,5))

  #plot accuarcy
  plt.subplot(221)
  plt.plot(history.history['accuracy'],label='acc')
  plt.plot(history.history['val_accuracy'],label='val_acc')
  plt.title('train_acc vs val_acc')
  plt.ylabel("accuracy")
  plt.xlabel("epochs")
  plt.legend()


  #plot loss
  plt.subplot(222)
  plt.plot(history.history['loss'],label='loss')
  plt.plot(history.history['val_loss'],label='val_loss')
  plt.title('train_loss vs val_loss')
  plt.ylabel("loss")
  plt.xlabel("epochs")
  plt.legend()

  plt.show()

plot_accuracy_loss(history)
# Out:
# Model: "sequential"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  conv2d (Conv2D)             (None, 54, 54, 96)        34944
#
#
#
#  max_pooling2d (MaxPooling2  (None, 26, 26, 96)        0
#
#  D)
#
#
#
#  batch_normalization (Batch  (None, 26, 26, 96)        384
#
#  Normalization)
#
#
#
#  conv2d_1 (Conv2D)           (None, 26, 26, 256)       614656
#
#
#
#  max_pooling2d_1 (MaxPoolin  (None, 12, 12, 256)       0
#
#  g2D)
#
#
#
#  batch_normalization_1 (Bat  (None, 12, 12, 256)       1024
#
#  chNormalization)
#
#
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 384)       885120
#
#
#
#  batch_normalization_2 (Bat  (None, 12, 12, 384)       1536
#
#  chNormalization)
#
#
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 384)       1327488
#
#
#
#  batch_normalization_3 (Bat  (None, 12, 12, 384)       1536
#
#  chNormalization)
#
#
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 256)       884992
#
#
#
#  max_pooling2d_2 (MaxPoolin  (None, 5, 5, 256)         0
#
#  g2D)
#
#
#
#  batch_normalization_4 (Bat  (None, 5, 5, 256)         1024
#
#  chNormalization)
#
#
#
#  flatten (Flatten)           (None, 6400)              0
#
#
#
#  dense (Dense)               (None, 4096)              26218496
#
#
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#
#
#  dense_2 (Dense)             (None, 9)                 36873
#
#
#
# =================================================================
#
# Total params: 46789385 (178.49 MB)
#
# Trainable params: 46786633 (178.48 MB)
#
# Non-trainable params: 2752 (10.75 KB)
#
# _________________________________________________________________
#
# Epoch 1/250
#
# 1326/1326 [==============================] - 43s 23ms/step - loss: 1.8761 - accuracy: 0.3725 - val_loss: 3.0499 - val_accuracy: 0.3515
#
# Epoch 2/250
#
# 1326/1326 [==============================] - 29s 22ms/step - loss: 1.3669 - accuracy: 0.4600 - val_loss: 2.4700 - val_accuracy: 0.3991
#
# Epoch 3/250
#
# 1326/1326 [==============================] - 29s 22ms/step - loss: 1.2340 - accuracy: 0.5037 - val_loss: 2.2531 - val_accuracy: 0.2676
#
# Epoch 4/250
#
# 1326/1326 [==============================] - 29s 22ms/step - loss: 1.1383 - accuracy: 0.5445 - val_loss: 1.3650 - val_accuracy: 0.4943
#
# Epoch 5/250
#
# 1326/1326 [==============================] - 29s 22ms/step - loss: 1.0865 - accuracy: 0.5734 - val_loss: 0.9239 - val_accuracy: 0.6259
#
# Epoch 6/250
#
# 1326/1326 [==============================] - 29s 22ms/step - loss: 1.0284 - accuracy: 0.5966 - val_loss: 1.2543 - val_accuracy: 0.5102
#
# Epoch 7/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.9422 - accuracy: 0.6364 - val_loss: 0.9512 - val_accuracy: 0.6576
#
# Epoch 8/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.7832 - accuracy: 0.7010 - val_loss: 0.9965 - val_accuracy: 0.6463
#
# Epoch 9/250
#
# 1326/1326 [==============================] - 30s 23ms/step - loss: 0.6727 - accuracy: 0.7516 - val_loss: 0.6773 - val_accuracy: 0.7619
#
# Epoch 10/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.5610 - accuracy: 0.7923 - val_loss: 1.4193 - val_accuracy: 0.5329
#
# Epoch 11/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.4803 - accuracy: 0.8273 - val_loss: 0.9523 - val_accuracy: 0.7052
#
# Epoch 12/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.4165 - accuracy: 0.8547 - val_loss: 0.8418 - val_accuracy: 0.7415
#
# Epoch 13/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.3598 - accuracy: 0.8750 - val_loss: 2.6004 - val_accuracy: 0.4422
#
# Epoch 14/250
#
# 1326/1326 [==============================] - 30s 23ms/step - loss: 0.3175 - accuracy: 0.8899 - val_loss: 0.5226 - val_accuracy: 0.8277
#
# Epoch 15/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.3048 - accuracy: 0.8971 - val_loss: 0.7641 - val_accuracy: 0.7664
#
# Epoch 16/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.2510 - accuracy: 0.9122 - val_loss: 0.9674 - val_accuracy: 0.7256
#
# Epoch 17/250
#
# 1326/1326 [==============================] - 30s 23ms/step - loss: 0.2341 - accuracy: 0.9199 - val_loss: 0.5333 - val_accuracy: 0.8435
#
# Epoch 18/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.2045 - accuracy: 0.9293 - val_loss: 2.9156 - val_accuracy: 0.4966
#
# Epoch 19/250
#
# 1326/1326 [==============================] - 30s 23ms/step - loss: 0.1995 - accuracy: 0.9325 - val_loss: 0.5821 - val_accuracy: 0.8481
#
# Epoch 20/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.1851 - accuracy: 0.9389 - val_loss: 1.5062 - val_accuracy: 0.6757
#
# Epoch 21/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.1569 - accuracy: 0.9472 - val_loss: 0.5846 - val_accuracy: 0.8458
#
# Epoch 22/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.1707 - accuracy: 0.9444 - val_loss: 0.7966 - val_accuracy: 0.8231
#
# Epoch 23/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.1535 - accuracy: 0.9510 - val_loss: 0.7924 - val_accuracy: 0.8163
#
# Epoch 24/250
#
# 1326/1326 [==============================] - 30s 23ms/step - loss: 0.1398 - accuracy: 0.9570 - val_loss: 0.4824 - val_accuracy: 0.8821
#
# Epoch 25/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.1368 - accuracy: 0.9586 - val_loss: 0.5230 - val_accuracy: 0.8821
#
# Epoch 26/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.1221 - accuracy: 0.9610 - val_loss: 1.7603 - val_accuracy: 0.6757
#
# Epoch 27/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.1346 - accuracy: 0.9591 - val_loss: 0.8359 - val_accuracy: 0.8322
#
# Epoch 28/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0972 - accuracy: 0.9692 - val_loss: 0.6974 - val_accuracy: 0.8458
#
# Epoch 29/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.1238 - accuracy: 0.9619 - val_loss: 0.6185 - val_accuracy: 0.8639
#
# Epoch 30/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.1044 - accuracy: 0.9674 - val_loss: 1.3749 - val_accuracy: 0.7914
#
# Epoch 31/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0920 - accuracy: 0.9705 - val_loss: 0.6281 - val_accuracy: 0.8481
#
# Epoch 32/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0966 - accuracy: 0.9694 - val_loss: 0.6810 - val_accuracy: 0.8798
#
# Epoch 33/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0958 - accuracy: 0.9733 - val_loss: 0.8825 - val_accuracy: 0.8254
#
# Epoch 34/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0836 - accuracy: 0.9738 - val_loss: 1.7391 - val_accuracy: 0.7029
#
# Epoch 35/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0796 - accuracy: 0.9774 - val_loss: 1.9615 - val_accuracy: 0.7188
#
# Epoch 36/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0841 - accuracy: 0.9756 - val_loss: 0.7150 - val_accuracy: 0.8662
#
# Epoch 37/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0829 - accuracy: 0.9733 - val_loss: 0.8823 - val_accuracy: 0.8254
#
# Epoch 38/250
#
# 1326/1326 [==============================] - 30s 23ms/step - loss: 0.0849 - accuracy: 0.9747 - val_loss: 0.6289 - val_accuracy: 0.8866
#
# Epoch 39/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0846 - accuracy: 0.9762 - val_loss: 2.4752 - val_accuracy: 0.6893
#
# Epoch 40/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0718 - accuracy: 0.9783 - val_loss: 0.8003 - val_accuracy: 0.8435
#
# Epoch 41/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0932 - accuracy: 0.9746 - val_loss: 0.7332 - val_accuracy: 0.8685
#
# Epoch 42/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0781 - accuracy: 0.9784 - val_loss: 2.9421 - val_accuracy: 0.6939
#
# Epoch 43/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0705 - accuracy: 0.9808 - val_loss: 0.5302 - val_accuracy: 0.8844
#
# Epoch 44/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0782 - accuracy: 0.9766 - val_loss: 0.5756 - val_accuracy: 0.8685
#
# Epoch 45/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0563 - accuracy: 0.9825 - val_loss: 0.7211 - val_accuracy: 0.8617
#
# Epoch 46/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0877 - accuracy: 0.9755 - val_loss: 1.5278 - val_accuracy: 0.7574
#
# Epoch 47/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0703 - accuracy: 0.9795 - val_loss: 0.8299 - val_accuracy: 0.8707
#
# Epoch 48/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0776 - accuracy: 0.9787 - val_loss: 1.2225 - val_accuracy: 0.7823
#
# Epoch 49/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0486 - accuracy: 0.9849 - val_loss: 0.8861 - val_accuracy: 0.8549
#
# Epoch 50/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0858 - accuracy: 0.9781 - val_loss: 1.0004 - val_accuracy: 0.8299
#
# Epoch 51/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0635 - accuracy: 0.9827 - val_loss: 1.1930 - val_accuracy: 0.7642
#
# Epoch 52/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0729 - accuracy: 0.9810 - val_loss: 0.7510 - val_accuracy: 0.8639
#
# Epoch 53/250
#
# 1326/1326 [==============================] - 30s 23ms/step - loss: 0.0541 - accuracy: 0.9857 - val_loss: 0.6822 - val_accuracy: 0.8912
#
# Epoch 54/250
#
# 1326/1326 [==============================] - 30s 23ms/step - loss: 0.0697 - accuracy: 0.9808 - val_loss: 0.6771 - val_accuracy: 0.9070
#
# Epoch 55/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0531 - accuracy: 0.9853 - val_loss: 0.7748 - val_accuracy: 0.8594
#
# Epoch 56/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0631 - accuracy: 0.9844 - val_loss: 1.2113 - val_accuracy: 0.8209
#
# Epoch 57/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0700 - accuracy: 0.9799 - val_loss: 0.6590 - val_accuracy: 0.8889
#
# Epoch 58/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0493 - accuracy: 0.9864 - val_loss: 3.3896 - val_accuracy: 0.4467
#
# Epoch 59/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0619 - accuracy: 0.9834 - val_loss: 1.0492 - val_accuracy: 0.8186
#
# Epoch 60/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0435 - accuracy: 0.9873 - val_loss: 1.5684 - val_accuracy: 0.7823
#
# Epoch 61/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0666 - accuracy: 0.9824 - val_loss: 0.7049 - val_accuracy: 0.9070
#
# Epoch 62/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0466 - accuracy: 0.9877 - val_loss: 0.8208 - val_accuracy: 0.8707
#
# Epoch 63/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0508 - accuracy: 0.9872 - val_loss: 1.3128 - val_accuracy: 0.8254
#
# Epoch 64/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0667 - accuracy: 0.9831 - val_loss: 0.9078 - val_accuracy: 0.8685
#
# Epoch 65/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0646 - accuracy: 0.9835 - val_loss: 0.5780 - val_accuracy: 0.8798
#
# Epoch 66/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0499 - accuracy: 0.9877 - val_loss: 0.8354 - val_accuracy: 0.8141
#
# Epoch 67/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0666 - accuracy: 0.9829 - val_loss: 1.2498 - val_accuracy: 0.8753
#
# Epoch 68/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0374 - accuracy: 0.9909 - val_loss: 1.2416 - val_accuracy: 0.7800
#
# Epoch 69/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0280 - accuracy: 0.9926 - val_loss: 2.2625 - val_accuracy: 0.8435
#
# Epoch 70/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0727 - accuracy: 0.9838 - val_loss: 0.9146 - val_accuracy: 0.8776
#
# Epoch 71/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0664 - accuracy: 0.9855 - val_loss: 0.8761 - val_accuracy: 0.8776
#
# Epoch 72/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0348 - accuracy: 0.9898 - val_loss: 1.9930 - val_accuracy: 0.7256
#
# Epoch 73/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0544 - accuracy: 0.9871 - val_loss: 0.6286 - val_accuracy: 0.8957
#
# Epoch 74/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0569 - accuracy: 0.9859 - val_loss: 0.9412 - val_accuracy: 0.8889
#
# Epoch 75/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0446 - accuracy: 0.9877 - val_loss: 0.6428 - val_accuracy: 0.8980
#
# Epoch 76/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0567 - accuracy: 0.9866 - val_loss: 5.0520 - val_accuracy: 0.5215
#
# Epoch 77/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0471 - accuracy: 0.9868 - val_loss: 0.9811 - val_accuracy: 0.8435
#
# Epoch 78/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0571 - accuracy: 0.9873 - val_loss: 0.7861 - val_accuracy: 0.7959
#
# Epoch 79/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0671 - accuracy: 0.9846 - val_loss: 0.8049 - val_accuracy: 0.8821
#
# Epoch 80/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0308 - accuracy: 0.9913 - val_loss: 0.7157 - val_accuracy: 0.8617
#
# Epoch 81/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0399 - accuracy: 0.9893 - val_loss: 1.3962 - val_accuracy: 0.8209
#
# Epoch 82/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0474 - accuracy: 0.9893 - val_loss: 0.9041 - val_accuracy: 0.8571
#
# Epoch 83/250
#
# 1326/1326 [==============================] - 30s 22ms/step - loss: 0.0466 - accuracy: 0.9883 - val_loss: 0.8566 - val_accuracy: 0.8458
#
# Epoch 84/250
#
# 1326/1326 [==============================] - 30s 23ms/step - loss: 0.0453 - accuracy: 0.9884 - val_loss: 0.8376 - val_accuracy: 0.8685
#
# 14/14 [==============================] - 1s 48ms/step - loss: 0.7326 - accuracy: 0.8623
#
# 14/14 [==============================] - 0s 14ms/step
#
#               precision    recall  f1-score   support
#
#
#
#            0       0.85      0.67      0.75        51
#
#            1       1.00      0.97      0.99        39
#
#            2       0.97      0.86      0.91        73
#
#            3       0.71      0.81      0.76        27
#
#            4       0.81      0.78      0.79        49
#
#            5       0.89      0.87      0.88        38
#
#            6       0.80      1.00      0.89        52
#
#            7       0.94      0.91      0.92        64
#
#            8       0.76      0.88      0.81        50
#
#
#
#     accuracy                           0.86       443
#
#    macro avg       0.86      0.86      0.86       443
#
# weighted avg       0.87      0.86      0.86       443

# %%
from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate,Flatten, Dense, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense


# this could also be the output a different Keras model or layer
input_tensor = Input(shape=(224, 224, 3))

base_model = VGG19(input_tensor=input_tensor, weights=None,
                    include_top=False )
base_model.trainable = True
x = base_model.output
x=Flatten()(x)
x=Dense(128,activation='relu')(x)
x=Dense(64,activation='relu')(x)
x= Dense(9, activation='softmax')(x)


opt = keras.optimizers.Adam(learning_rate=0.00001)
model2= Model(inputs=input_tensor, outputs=x)

model2.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
"""for layer in model.layers:
   layer.trainable = True"""
#model.summary()

model_checkpoint_callback = keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=30,restore_best_weights=True)

history = model2.fit(train_images, train_lables, batch_size=8, epochs=250,

        validation_data=(valid_images, valid_lables), callbacks=[model_checkpoint_callback])

#callbacks = [EarlyStopping(monitor='loss', patience=5)]
test_loss=model2.evaluate(test_images,test_lables)
predictions=model2.predict(test_images)
pred_lables=np.argmax(predictions,axis=1)
print(classification_report(test_lables,pred_lables))

def plot_accuracy_loss(history):
  fig=plt.figure(figsize=(10,5))

  #plot accuarcy
  plt.subplot(221)
  plt.plot(history.history['accuracy'],label='acc')
  plt.plot(history.history['val_accuracy'],label='val_acc')
  plt.title('train_acc vs val_acc')
  plt.ylabel("accuracy")
  plt.xlabel("epochs")
  plt.legend()


  #plot loss
  plt.subplot(222)
  plt.plot(history.history['loss'],label='loss')
  plt.plot(history.history['val_loss'],label='val_loss')
  plt.title('train_loss vs val_loss')
  plt.ylabel("loss")
  plt.xlabel("epochs")
  plt.legend()

  plt.show()

plot_accuracy_loss(history)
# Out:
# Epoch 1/250
# 1326/1326 [==============================] - 259s 186ms/step - loss: 1.4740 - accuracy: 0.4016 - val_loss: 1.1295 - val_accuracy: 0.5624
# Epoch 2/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 1.0985 - accuracy: 0.5667 - val_loss: 0.9679 - val_accuracy: 0.6349
# Epoch 3/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.9530 - accuracy: 0.6300 - val_loss: 0.8216 - val_accuracy: 0.6667
# Epoch 4/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.8422 - accuracy: 0.6811 - val_loss: 0.7823 - val_accuracy: 0.7029
# Epoch 5/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.7177 - accuracy: 0.7319 - val_loss: 0.7007 - val_accuracy: 0.7256
# Epoch 6/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.6035 - accuracy: 0.7771 - val_loss: 0.5876 - val_accuracy: 0.7846
# Epoch 7/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.5052 - accuracy: 0.8099 - val_loss: 0.5540 - val_accuracy: 0.8073
# Epoch 8/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.4283 - accuracy: 0.8355 - val_loss: 0.5631 - val_accuracy: 0.7823
# Epoch 9/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.3584 - accuracy: 0.8663 - val_loss: 0.5778 - val_accuracy: 0.8095
# Epoch 10/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.3002 - accuracy: 0.8851 - val_loss: 0.5735 - val_accuracy: 0.8322
# Epoch 11/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.2479 - accuracy: 0.9087 - val_loss: 0.6270 - val_accuracy: 0.8118
# Epoch 12/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.2061 - accuracy: 0.9217 - val_loss: 0.6726 - val_accuracy: 0.8209
# Epoch 13/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.1752 - accuracy: 0.9353 - val_loss: 0.7217 - val_accuracy: 0.8118
# Epoch 14/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.1539 - accuracy: 0.9443 - val_loss: 0.6023 - val_accuracy: 0.8231
# Epoch 15/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.1333 - accuracy: 0.9547 - val_loss: 0.8561 - val_accuracy: 0.8005
# Epoch 16/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.1115 - accuracy: 0.9607 - val_loss: 0.8114 - val_accuracy: 0.8277
# Epoch 17/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0977 - accuracy: 0.9642 - val_loss: 0.8250 - val_accuracy: 0.8095
# Epoch 18/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.1019 - accuracy: 0.9649 - val_loss: 0.8077 - val_accuracy: 0.8277
# Epoch 19/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0866 - accuracy: 0.9725 - val_loss: 0.8659 - val_accuracy: 0.8367
# Epoch 20/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0811 - accuracy: 0.9735 - val_loss: 0.9514 - val_accuracy: 0.8050
# Epoch 21/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0973 - accuracy: 0.9706 - val_loss: 0.7176 - val_accuracy: 0.8163
# Epoch 22/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0568 - accuracy: 0.9814 - val_loss: 0.8886 - val_accuracy: 0.8141
# Epoch 23/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0673 - accuracy: 0.9783 - val_loss: 0.9174 - val_accuracy: 0.8005
# Epoch 24/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0570 - accuracy: 0.9823 - val_loss: 1.0032 - val_accuracy: 0.8231
# Epoch 25/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0697 - accuracy: 0.9771 - val_loss: 0.9727 - val_accuracy: 0.8118
# Epoch 26/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0651 - accuracy: 0.9782 - val_loss: 0.8017 - val_accuracy: 0.8390
# Epoch 27/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0611 - accuracy: 0.9803 - val_loss: 0.8900 - val_accuracy: 0.8186
# Epoch 28/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0516 - accuracy: 0.9846 - val_loss: 0.9352 - val_accuracy: 0.8163
# Epoch 29/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0454 - accuracy: 0.9859 - val_loss: 1.0368 - val_accuracy: 0.8118
# Epoch 30/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0497 - accuracy: 0.9827 - val_loss: 1.2944 - val_accuracy: 0.7891
# Epoch 31/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0509 - accuracy: 0.9836 - val_loss: 0.9238 - val_accuracy: 0.8322
# Epoch 32/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0509 - accuracy: 0.9824 - val_loss: 0.9227 - val_accuracy: 0.8186
# Epoch 33/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0363 - accuracy: 0.9886 - val_loss: 1.0187 - val_accuracy: 0.8413
# Epoch 34/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0502 - accuracy: 0.9865 - val_loss: 0.8998 - val_accuracy: 0.8322
# Epoch 35/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0420 - accuracy: 0.9854 - val_loss: 0.9977 - val_accuracy: 0.8163
# Epoch 36/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0377 - accuracy: 0.9888 - val_loss: 0.9404 - val_accuracy: 0.8209
# Epoch 37/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0384 - accuracy: 0.9892 - val_loss: 1.0634 - val_accuracy: 0.8413
# Epoch 38/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0352 - accuracy: 0.9905 - val_loss: 0.9274 - val_accuracy: 0.8435
# Epoch 39/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0374 - accuracy: 0.9890 - val_loss: 1.0478 - val_accuracy: 0.8118
# Epoch 40/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0391 - accuracy: 0.9877 - val_loss: 0.9462 - val_accuracy: 0.8413
# Epoch 41/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0306 - accuracy: 0.9904 - val_loss: 1.0203 - val_accuracy: 0.8095
# Epoch 42/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0358 - accuracy: 0.9892 - val_loss: 0.8766 - val_accuracy: 0.8413
# Epoch 43/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0308 - accuracy: 0.9908 - val_loss: 0.9437 - val_accuracy: 0.8503
# Epoch 44/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0285 - accuracy: 0.9930 - val_loss: 0.9256 - val_accuracy: 0.8367
# Epoch 45/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0347 - accuracy: 0.9903 - val_loss: 0.9617 - val_accuracy: 0.8458
# Epoch 46/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0244 - accuracy: 0.9924 - val_loss: 1.1267 - val_accuracy: 0.8413
# Epoch 47/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0363 - accuracy: 0.9884 - val_loss: 1.1004 - val_accuracy: 0.8299
# Epoch 48/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0226 - accuracy: 0.9930 - val_loss: 1.1074 - val_accuracy: 0.8322
# Epoch 49/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0319 - accuracy: 0.9899 - val_loss: 1.5331 - val_accuracy: 0.7982
# Epoch 50/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0303 - accuracy: 0.9923 - val_loss: 1.2654 - val_accuracy: 0.8141
# Epoch 51/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0301 - accuracy: 0.9924 - val_loss: 1.0255 - val_accuracy: 0.8322
# Epoch 52/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0237 - accuracy: 0.9930 - val_loss: 0.9658 - val_accuracy: 0.8390
# Epoch 53/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0269 - accuracy: 0.9908 - val_loss: 0.9799 - val_accuracy: 0.8435
# Epoch 54/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0118 - accuracy: 0.9971 - val_loss: 1.2745 - val_accuracy: 0.8503
# Epoch 55/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 1.2865e-04 - accuracy: 1.0000 - val_loss: 1.3661 - val_accuracy: 0.8571
# Epoch 56/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 2.4654e-05 - accuracy: 1.0000 - val_loss: 1.4303 - val_accuracy: 0.8549
# Epoch 57/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 1.1651e-05 - accuracy: 1.0000 - val_loss: 1.5187 - val_accuracy: 0.8503
# Epoch 58/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 5.6226e-06 - accuracy: 1.0000 - val_loss: 1.6042 - val_accuracy: 0.8503
# Epoch 59/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 2.6887e-06 - accuracy: 1.0000 - val_loss: 1.6959 - val_accuracy: 0.8503
# Epoch 60/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 1.2635e-06 - accuracy: 1.0000 - val_loss: 1.7864 - val_accuracy: 0.8481
# Epoch 61/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 5.9966e-07 - accuracy: 1.0000 - val_loss: 1.8845 - val_accuracy: 0.8481
# Epoch 62/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 2.7995e-07 - accuracy: 1.0000 - val_loss: 1.9835 - val_accuracy: 0.8435
# Epoch 63/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 1.3271e-07 - accuracy: 1.0000 - val_loss: 2.0713 - val_accuracy: 0.8458
# Epoch 64/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 6.3841e-08 - accuracy: 1.0000 - val_loss: 2.1637 - val_accuracy: 0.8435
# Epoch 65/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 3.0982e-08 - accuracy: 1.0000 - val_loss: 2.2442 - val_accuracy: 0.8435
# Epoch 66/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 1.5193e-08 - accuracy: 1.0000 - val_loss: 2.3182 - val_accuracy: 0.8435
# Epoch 67/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 7.9113e-09 - accuracy: 1.0000 - val_loss: 2.3846 - val_accuracy: 0.8435
# Epoch 68/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 4.2366e-09 - accuracy: 1.0000 - val_loss: 2.4195 - val_accuracy: 0.8435
# Epoch 69/250
# 1326/1326 [==============================] - 244s 184ms/step - loss: 2.6633e-09 - accuracy: 1.0000 - val_loss: 2.4141 - val_accuracy: 0.8435
# Epoch 70/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 2.2363e-09 - accuracy: 1.0000 - val_loss: 2.3923 - val_accuracy: 0.8435
# Epoch 71/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 2.0228e-09 - accuracy: 1.0000 - val_loss: 2.3946 - val_accuracy: 0.8481
# Epoch 72/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 1.6969e-09 - accuracy: 1.0000 - val_loss: 2.3534 - val_accuracy: 0.8458
# Epoch 73/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 1.7306e-09 - accuracy: 1.0000 - val_loss: 2.3553 - val_accuracy: 0.8458
# Epoch 74/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0270 - accuracy: 0.9962 - val_loss: 1.1562 - val_accuracy: 0.7710
# Epoch 75/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0337 - accuracy: 0.9887 - val_loss: 1.1666 - val_accuracy: 0.8435
# Epoch 76/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0333 - accuracy: 0.9899 - val_loss: 0.8719 - val_accuracy: 0.8458
# Epoch 77/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0177 - accuracy: 0.9943 - val_loss: 1.1527 - val_accuracy: 0.8231
# Epoch 78/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0221 - accuracy: 0.9946 - val_loss: 0.9087 - val_accuracy: 0.8549
# Epoch 79/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0370 - accuracy: 0.9886 - val_loss: 0.9636 - val_accuracy: 0.8435
# Epoch 80/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0193 - accuracy: 0.9944 - val_loss: 0.9658 - val_accuracy: 0.8209
# Epoch 81/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0167 - accuracy: 0.9947 - val_loss: 0.9422 - val_accuracy: 0.8549
# Epoch 82/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0302 - accuracy: 0.9925 - val_loss: 0.8654 - val_accuracy: 0.8299
# Epoch 83/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0215 - accuracy: 0.9941 - val_loss: 1.0360 - val_accuracy: 0.8231
# Epoch 84/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0169 - accuracy: 0.9942 - val_loss: 1.3155 - val_accuracy: 0.7959
# Epoch 85/250
# 1326/1326 [==============================] - 245s 185ms/step - loss: 0.0109 - accuracy: 0.9972 - val_loss: 1.4657 - val_accuracy: 0.8367
# 14/14 [==============================] - 11s 470ms/step - loss: 1.3156 - accuracy: 0.8284
# 14/14 [==============================] - 2s 155ms/step
#               precision    recall  f1-score   support
#
#            0       0.83      0.67      0.74        51
#            1       0.97      0.95      0.96        39
#            2       0.90      0.89      0.90        73
#            3       0.72      0.85      0.78        27
#            4       0.63      0.63      0.63        49
#            5       0.95      0.92      0.93        38
#            6       0.82      0.90      0.86        52
#            7       0.92      0.94      0.93        64
#            8       0.67      0.70      0.69        50
#
#     accuracy                           0.83       443
#    macro avg       0.82      0.83      0.82       443
# weighted avg       0.83      0.83      0.83       443

# %%
from keras.models import Model
from keras.layers import Input, Activation, Concatenate
from keras.layers import Dropout
from keras.layers import Convolution2D, MaxPooling2D
from keras.layers import GlobalAveragePooling2D
from keras import regularizers
import keras
def fire_module(input_fire, s1, e1, e3, weight_decay_l2, fireID):
    '''
    A wrapper to build fire module

    # Arguments
        input_fire: input activations
        s1: number of filters for squeeze step
        e1: number of filters for 1x1 expansion step
        e3: number of filters for 3x3 expansion step
        weight_decay_l2: weight decay for conv layers
        fireID: ID for the module

    # Return
        Output activations
    '''

    # Squezee step
    output_squeeze = Convolution2D(
        s1, (1, 1), activation='relu',
        kernel_initializer='glorot_uniform',
        kernel_regularizer=regularizers.l2(weight_decay_l2),
        padding='same', name='fire' + str(fireID) + '_squeeze',
        data_format="channels_last")(input_fire)
    # Expansion steps
    output_expand1 = Convolution2D(
        e1, (1, 1), activation='relu',
        kernel_initializer='glorot_uniform',
        kernel_regularizer=regularizers.l2(weight_decay_l2),
        padding='same', name='fire' + str(fireID) + '_expand1',
        data_format="channels_last")(output_squeeze)
    output_expand2 = Convolution2D(
        e3, (3, 3), activation='relu',
        kernel_initializer='glorot_uniform',
        kernel_regularizer=regularizers.l2(weight_decay_l2),
        padding='same', name='fire' + str(fireID) + '_expand2',
        data_format="channels_last")(output_squeeze)
    # Merge expanded activations
    output_fire = Concatenate(axis=3)([output_expand1, output_expand2])
    return output_fire

def SqueezeNet(num_classes, weight_decay_l2=0.00001, inputs=(224, 224, 3)):
    '''
    A wrapper to build SqueezeNet Model

    # Arguments
        num_classes: number of classes defined for classification task
        weight_decay_l2: weight decay for conv layers
        inputs: input image dimensions

    # Return
        A SqueezeNet Keras Model
    '''
    input_img = Input(shape=inputs)

    conv1 = Convolution2D(
        32, (7, 7), activation='relu', kernel_initializer='glorot_uniform',
        strides=(2, 2), padding='same', name='conv1',
        data_format="channels_last")(input_img)

    maxpool1 = MaxPooling2D(
        pool_size=(2, 2), strides=(2, 2), name='maxpool1',
        data_format="channels_last")(conv1)

    fire2 = fire_module(maxpool1, 8, 16, 16, weight_decay_l2, 2)
    fire3 = fire_module(fire2, 8, 16, 16, weight_decay_l2, 3)
    fire4 = fire_module(fire3, 16, 32, 32, weight_decay_l2, 4)

    maxpool4 = MaxPooling2D(
        pool_size=(2, 2), strides=(2, 2), name='maxpool4',
        data_format="channels_last")(fire4)

    fire5 = fire_module(maxpool4, 16, 32, 32, weight_decay_l2, 5)
    fire6 = fire_module(fire5, 32, 64, 64, weight_decay_l2, 6)
    fire7 = fire_module(fire6, 32, 64, 64, weight_decay_l2, 7)
    fire8 = fire_module(fire7, 64, 128, 128, weight_decay_l2, 8)

    maxpool8 = MaxPooling2D(
        pool_size=(2, 2), strides=(2, 2), name='maxpool8',
        data_format="channels_last")(fire8)

    fire9 = fire_module(maxpool8, 64, 128, 128, weight_decay_l2, 9)

    conv10 = Convolution2D(
        num_classes, (1, 1), activation='relu', kernel_initializer='glorot_uniform',
        padding='valid', name='conv10',
        data_format="channels_last")(fire9)

    global_avgpool10 = GlobalAveragePooling2D(data_format='channels_last')(conv10)
    softmax = Activation("softmax", name='softmax')(global_avgpool10)

    return Model(inputs=input_img, outputs=softmax)


model = SqueezeNet(9)
model.summary()

opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model_checkpoint_callback = keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=30,restore_best_weights=True)

history = model.fit(train_images, train_lables, batch_size=8, epochs=250,

validation_data=(valid_images, valid_lables), callbacks=[model_checkpoint_callback])
test_loss=model.evaluate(test_images,test_lables)
predictions=model.predict(test_images)
pred_lables=np.argmax(predictions,axis=1)
print(classification_report(test_lables,pred_lables))
def plot_accuracy_loss(history):
  fig=plt.figure(figsize=(10,5))

  #plot accuarcy
  plt.subplot(221)
  plt.plot(history.history['accuracy'],label='acc')
  plt.plot(history.history['val_accuracy'],label='val_acc')
  plt.title('train_acc vs val_acc')
  plt.ylabel("accuracy")
  plt.xlabel("epochs")
  plt.legend()


  #plot loss
  plt.subplot(222)
  plt.plot(history.history['loss'],label='loss')
  plt.plot(history.history['val_loss'],label='val_loss')
  plt.title('train_loss vs val_loss')
  plt.ylabel("loss")
  plt.xlabel("epochs")
  plt.legend()

  plt.show()

plot_accuracy_loss(history)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv1 (Conv2D)              (None, 112, 112, 32)         4736      ['input_1[0][0]']
#
#  maxpool1 (MaxPooling2D)     (None, 56, 56, 32)           0         ['conv1[0][0]']
#
#  fire2_squeeze (Conv2D)      (None, 56, 56, 8)            264       ['maxpool1[0][0]']
#
#  fire2_expand1 (Conv2D)      (None, 56, 56, 16)           144       ['fire2_squeeze[0][0]']
#
#  fire2_expand2 (Conv2D)      (None, 56, 56, 16)           1168      ['fire2_squeeze[0][0]']
#
#  concatenate (Concatenate)   (None, 56, 56, 32)           0         ['fire2_expand1[0][0]',
#                                                                      'fire2_expand2[0][0]']
#
#  fire3_squeeze (Conv2D)      (None, 56, 56, 8)            264       ['concatenate[0][0]']
#
#  fire3_expand1 (Conv2D)      (None, 56, 56, 16)           144       ['fire3_squeeze[0][0]']
#
#  fire3_expand2 (Conv2D)      (None, 56, 56, 16)           1168      ['fire3_squeeze[0][0]']
#
#  concatenate_1 (Concatenate  (None, 56, 56, 32)           0         ['fire3_expand1[0][0]',
#  )                                                                   'fire3_expand2[0][0]']
#
#  fire4_squeeze (Conv2D)      (None, 56, 56, 16)           528       ['concatenate_1[0][0]']
#
#  fire4_expand1 (Conv2D)      (None, 56, 56, 32)           544       ['fire4_squeeze[0][0]']
#
#  fire4_expand2 (Conv2D)      (None, 56, 56, 32)           4640      ['fire4_squeeze[0][0]']
#
#  concatenate_2 (Concatenate  (None, 56, 56, 64)           0         ['fire4_expand1[0][0]',
#  )                                                                   'fire4_expand2[0][0]']
#
#  maxpool4 (MaxPooling2D)     (None, 28, 28, 64)           0         ['concatenate_2[0][0]']
#
#  fire5_squeeze (Conv2D)      (None, 28, 28, 16)           1040      ['maxpool4[0][0]']
#
#  fire5_expand1 (Conv2D)      (None, 28, 28, 32)           544       ['fire5_squeeze[0][0]']
#
#  fire5_expand2 (Conv2D)      (None, 28, 28, 32)           4640      ['fire5_squeeze[0][0]']
#
#  concatenate_3 (Concatenate  (None, 28, 28, 64)           0         ['fire5_expand1[0][0]',
#  )                                                                   'fire5_expand2[0][0]']
#
#  fire6_squeeze (Conv2D)      (None, 28, 28, 32)           2080      ['concatenate_3[0][0]']
#
#  fire6_expand1 (Conv2D)      (None, 28, 28, 64)           2112      ['fire6_squeeze[0][0]']
#
#  fire6_expand2 (Conv2D)      (None, 28, 28, 64)           18496     ['fire6_squeeze[0][0]']
#
#  concatenate_4 (Concatenate  (None, 28, 28, 128)          0         ['fire6_expand1[0][0]',
#  )                                                                   'fire6_expand2[0][0]']
#
#  fire7_squeeze (Conv2D)      (None, 28, 28, 32)           4128      ['concatenate_4[0][0]']
#
#  fire7_expand1 (Conv2D)      (None, 28, 28, 64)           2112      ['fire7_squeeze[0][0]']
#
#  fire7_expand2 (Conv2D)      (None, 28, 28, 64)           18496     ['fire7_squeeze[0][0]']
#
#  concatenate_5 (Concatenate  (None, 28, 28, 128)          0         ['fire7_expand1[0][0]',
#  )                                                                   'fire7_expand2[0][0]']
#
#  fire8_squeeze (Conv2D)      (None, 28, 28, 64)           8256      ['concatenate_5[0][0]']
#
#  fire8_expand1 (Conv2D)      (None, 28, 28, 128)          8320      ['fire8_squeeze[0][0]']
#
#  fire8_expand2 (Conv2D)      (None, 28, 28, 128)          73856     ['fire8_squeeze[0][0]']
#
#  concatenate_6 (Concatenate  (None, 28, 28, 256)          0         ['fire8_expand1[0][0]',
#  )                                                                   'fire8_expand2[0][0]']
#
#  maxpool8 (MaxPooling2D)     (None, 14, 14, 256)          0         ['concatenate_6[0][0]']
#
#  fire9_squeeze (Conv2D)      (None, 14, 14, 64)           16448     ['maxpool8[0][0]']
#
#  fire9_expand1 (Conv2D)      (None, 14, 14, 128)          8320      ['fire9_squeeze[0][0]']
#
#  fire9_expand2 (Conv2D)      (None, 14, 14, 128)          73856     ['fire9_squeeze[0][0]']
#
#  concatenate_7 (Concatenate  (None, 14, 14, 256)          0         ['fire9_expand1[0][0]',
#  )                                                                   'fire9_expand2[0][0]']
#
#  conv10 (Conv2D)             (None, 14, 14, 9)            2313      ['concatenate_7[0][0]']
#
#  global_average_pooling2d (  (None, 9)                    0         ['conv10[0][0]']
#  GlobalAveragePooling2D)
#
#  softmax (Activation)        (None, 9)                    0         ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 258617 (1010.22 KB)
# Trainable params: 258617 (1010.22 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/250
# 1326/1326 [==============================] - 28s 13ms/step - loss: 1.6942 - accuracy: 0.3131 - val_loss: 1.3631 - val_accuracy: 0.4218
# Epoch 2/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 1.3359 - accuracy: 0.4531 - val_loss: 1.1556 - val_accuracy: 0.4875
# Epoch 3/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 1.2407 - accuracy: 0.5001 - val_loss: 1.1466 - val_accuracy: 0.5261
# Epoch 4/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 1.1656 - accuracy: 0.5462 - val_loss: 1.0770 - val_accuracy: 0.5918
# Epoch 5/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 1.0986 - accuracy: 0.5743 - val_loss: 0.9495 - val_accuracy: 0.6190
# Epoch 6/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 1.0100 - accuracy: 0.6222 - val_loss: 0.8981 - val_accuracy: 0.6780
# Epoch 7/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.9149 - accuracy: 0.6589 - val_loss: 0.7936 - val_accuracy: 0.7302
# Epoch 8/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.8335 - accuracy: 0.6944 - val_loss: 0.8544 - val_accuracy: 0.6848
# Epoch 9/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.7815 - accuracy: 0.7088 - val_loss: 0.6682 - val_accuracy: 0.7687
# Epoch 10/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.7362 - accuracy: 0.7236 - val_loss: 0.6237 - val_accuracy: 0.8186
# Epoch 11/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.6942 - accuracy: 0.7394 - val_loss: 0.6234 - val_accuracy: 0.8209
# Epoch 12/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.6592 - accuracy: 0.7588 - val_loss: 0.7866 - val_accuracy: 0.7415
# Epoch 13/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.6209 - accuracy: 0.7789 - val_loss: 0.6445 - val_accuracy: 0.7528
# Epoch 14/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.5910 - accuracy: 0.7880 - val_loss: 0.5224 - val_accuracy: 0.8277
# Epoch 15/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.5710 - accuracy: 0.7985 - val_loss: 0.5629 - val_accuracy: 0.7959
# Epoch 16/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.5374 - accuracy: 0.8116 - val_loss: 0.5513 - val_accuracy: 0.8186
# Epoch 17/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.5088 - accuracy: 0.8241 - val_loss: 0.4932 - val_accuracy: 0.8435
# Epoch 18/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.4895 - accuracy: 0.8325 - val_loss: 0.6373 - val_accuracy: 0.7868
# Epoch 19/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.4628 - accuracy: 0.8410 - val_loss: 0.4234 - val_accuracy: 0.8571
# Epoch 20/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.4371 - accuracy: 0.8502 - val_loss: 0.3935 - val_accuracy: 0.8685
# Epoch 21/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.4309 - accuracy: 0.8582 - val_loss: 0.4603 - val_accuracy: 0.8662
# Epoch 22/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.4051 - accuracy: 0.8659 - val_loss: 0.4280 - val_accuracy: 0.8367
# Epoch 23/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.3948 - accuracy: 0.8679 - val_loss: 0.4781 - val_accuracy: 0.8571
# Epoch 24/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.3825 - accuracy: 0.8722 - val_loss: 0.4717 - val_accuracy: 0.8526
# Epoch 25/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.3703 - accuracy: 0.8759 - val_loss: 0.3956 - val_accuracy: 0.8776
# Epoch 26/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.3542 - accuracy: 0.8837 - val_loss: 0.3822 - val_accuracy: 0.8753
# Epoch 27/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.3357 - accuracy: 0.8905 - val_loss: 0.3833 - val_accuracy: 0.8730
# Epoch 28/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.3370 - accuracy: 0.8897 - val_loss: 0.4677 - val_accuracy: 0.8571
# Epoch 29/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.3256 - accuracy: 0.8980 - val_loss: 0.4054 - val_accuracy: 0.8594
# Epoch 30/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.3182 - accuracy: 0.8979 - val_loss: 0.6469 - val_accuracy: 0.8186
# Epoch 31/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.3008 - accuracy: 0.9038 - val_loss: 0.4237 - val_accuracy: 0.8662
# Epoch 32/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.2945 - accuracy: 0.9031 - val_loss: 0.3432 - val_accuracy: 0.8889
# Epoch 33/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.2778 - accuracy: 0.9049 - val_loss: 0.3811 - val_accuracy: 0.8912
# Epoch 34/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.2720 - accuracy: 0.9123 - val_loss: 0.4357 - val_accuracy: 0.8571
# Epoch 35/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.2611 - accuracy: 0.9146 - val_loss: 0.4647 - val_accuracy: 0.8776
# Epoch 36/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.2594 - accuracy: 0.9170 - val_loss: 0.3459 - val_accuracy: 0.8889
# Epoch 37/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.2394 - accuracy: 0.9223 - val_loss: 0.4595 - val_accuracy: 0.8753
# Epoch 38/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.2426 - accuracy: 0.9216 - val_loss: 0.3890 - val_accuracy: 0.8912
# Epoch 39/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.2468 - accuracy: 0.9178 - val_loss: 0.3540 - val_accuracy: 0.9025
# Epoch 40/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.2196 - accuracy: 0.9297 - val_loss: 0.3618 - val_accuracy: 0.8798
# Epoch 41/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.2130 - accuracy: 0.9299 - val_loss: 0.4098 - val_accuracy: 0.8753
# Epoch 42/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.2176 - accuracy: 0.9301 - val_loss: 0.3662 - val_accuracy: 0.8957
# Epoch 43/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.2006 - accuracy: 0.9343 - val_loss: 0.4776 - val_accuracy: 0.8639
# Epoch 44/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1971 - accuracy: 0.9380 - val_loss: 0.4992 - val_accuracy: 0.8503
# Epoch 45/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1886 - accuracy: 0.9394 - val_loss: 0.4068 - val_accuracy: 0.8776
# Epoch 46/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1908 - accuracy: 0.9368 - val_loss: 0.4185 - val_accuracy: 0.8844
# Epoch 47/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1895 - accuracy: 0.9397 - val_loss: 0.3255 - val_accuracy: 0.9048
# Epoch 48/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1790 - accuracy: 0.9423 - val_loss: 0.5654 - val_accuracy: 0.8549
# Epoch 49/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1754 - accuracy: 0.9467 - val_loss: 0.4125 - val_accuracy: 0.8776
# Epoch 50/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1812 - accuracy: 0.9436 - val_loss: 0.3677 - val_accuracy: 0.8980
# Epoch 51/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1610 - accuracy: 0.9486 - val_loss: 0.3968 - val_accuracy: 0.9048
# Epoch 52/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1642 - accuracy: 0.9485 - val_loss: 0.4262 - val_accuracy: 0.8889
# Epoch 53/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1455 - accuracy: 0.9526 - val_loss: 0.4653 - val_accuracy: 0.8730
# Epoch 54/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1518 - accuracy: 0.9517 - val_loss: 0.4113 - val_accuracy: 0.9048
# Epoch 55/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1441 - accuracy: 0.9540 - val_loss: 0.3556 - val_accuracy: 0.9025
# Epoch 56/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1355 - accuracy: 0.9560 - val_loss: 0.5471 - val_accuracy: 0.8526
# Epoch 57/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1314 - accuracy: 0.9597 - val_loss: 0.5229 - val_accuracy: 0.8685
# Epoch 58/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1362 - accuracy: 0.9560 - val_loss: 0.4487 - val_accuracy: 0.9070
# Epoch 59/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1224 - accuracy: 0.9641 - val_loss: 0.4485 - val_accuracy: 0.8912
# Epoch 60/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1179 - accuracy: 0.9622 - val_loss: 0.5024 - val_accuracy: 0.8957
# Epoch 61/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1226 - accuracy: 0.9622 - val_loss: 0.4860 - val_accuracy: 0.8934
# Epoch 62/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1137 - accuracy: 0.9638 - val_loss: 0.4836 - val_accuracy: 0.8798
# Epoch 63/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1175 - accuracy: 0.9632 - val_loss: 0.4896 - val_accuracy: 0.8957
# Epoch 64/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1133 - accuracy: 0.9652 - val_loss: 0.3868 - val_accuracy: 0.9048
# Epoch 65/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0993 - accuracy: 0.9696 - val_loss: 0.4483 - val_accuracy: 0.9116
# Epoch 66/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1131 - accuracy: 0.9670 - val_loss: 0.3961 - val_accuracy: 0.8912
# Epoch 67/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1066 - accuracy: 0.9643 - val_loss: 0.4490 - val_accuracy: 0.9070
# Epoch 68/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0907 - accuracy: 0.9721 - val_loss: 0.4968 - val_accuracy: 0.8934
# Epoch 69/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0941 - accuracy: 0.9724 - val_loss: 0.5537 - val_accuracy: 0.8957
# Epoch 70/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1065 - accuracy: 0.9680 - val_loss: 0.3764 - val_accuracy: 0.9025
# Epoch 71/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0841 - accuracy: 0.9770 - val_loss: 0.4788 - val_accuracy: 0.9002
# Epoch 72/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0873 - accuracy: 0.9753 - val_loss: 0.5348 - val_accuracy: 0.8934
# Epoch 73/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.1055 - accuracy: 0.9699 - val_loss: 0.5002 - val_accuracy: 0.8821
# Epoch 74/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0915 - accuracy: 0.9718 - val_loss: 0.4341 - val_accuracy: 0.8957
# Epoch 75/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0776 - accuracy: 0.9794 - val_loss: 0.5356 - val_accuracy: 0.8821
# Epoch 76/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0881 - accuracy: 0.9749 - val_loss: 0.4906 - val_accuracy: 0.8957
# Epoch 77/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0890 - accuracy: 0.9746 - val_loss: 0.4585 - val_accuracy: 0.8957
# Epoch 78/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0880 - accuracy: 0.9743 - val_loss: 0.4292 - val_accuracy: 0.8980
# Epoch 79/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0880 - accuracy: 0.9759 - val_loss: 0.4950 - val_accuracy: 0.8980
# Epoch 80/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0758 - accuracy: 0.9779 - val_loss: 0.3657 - val_accuracy: 0.8980
# Epoch 81/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0774 - accuracy: 0.9813 - val_loss: 0.4200 - val_accuracy: 0.9116
# Epoch 82/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0765 - accuracy: 0.9792 - val_loss: 0.4481 - val_accuracy: 0.8821
# Epoch 83/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0627 - accuracy: 0.9822 - val_loss: 0.6291 - val_accuracy: 0.8776
# Epoch 84/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0909 - accuracy: 0.9768 - val_loss: 0.4439 - val_accuracy: 0.8753
# Epoch 85/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0758 - accuracy: 0.9801 - val_loss: 0.5269 - val_accuracy: 0.8912
# Epoch 86/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0605 - accuracy: 0.9843 - val_loss: 0.4632 - val_accuracy: 0.9002
# Epoch 87/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0677 - accuracy: 0.9823 - val_loss: 0.4773 - val_accuracy: 0.9093
# Epoch 88/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0739 - accuracy: 0.9786 - val_loss: 0.4306 - val_accuracy: 0.9048
# Epoch 89/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0713 - accuracy: 0.9821 - val_loss: 0.4275 - val_accuracy: 0.9161
# Epoch 90/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0627 - accuracy: 0.9844 - val_loss: 0.4489 - val_accuracy: 0.9048
# Epoch 91/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0773 - accuracy: 0.9798 - val_loss: 0.4266 - val_accuracy: 0.9116
# Epoch 92/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0623 - accuracy: 0.9857 - val_loss: 0.7163 - val_accuracy: 0.8639
# Epoch 93/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0729 - accuracy: 0.9811 - val_loss: 0.4599 - val_accuracy: 0.9025
# Epoch 94/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0613 - accuracy: 0.9844 - val_loss: 0.5496 - val_accuracy: 0.8776
# Epoch 95/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0620 - accuracy: 0.9825 - val_loss: 0.5499 - val_accuracy: 0.9048
# Epoch 96/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0509 - accuracy: 0.9893 - val_loss: 0.4472 - val_accuracy: 0.9184
# Epoch 97/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0634 - accuracy: 0.9846 - val_loss: 0.4253 - val_accuracy: 0.8934
# Epoch 98/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0583 - accuracy: 0.9869 - val_loss: 0.4724 - val_accuracy: 0.9070
# Epoch 99/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0665 - accuracy: 0.9826 - val_loss: 0.5162 - val_accuracy: 0.9002
# Epoch 100/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0561 - accuracy: 0.9873 - val_loss: 0.5143 - val_accuracy: 0.9002
# Epoch 101/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0579 - accuracy: 0.9872 - val_loss: 0.4205 - val_accuracy: 0.9229
# Epoch 102/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0520 - accuracy: 0.9882 - val_loss: 0.4230 - val_accuracy: 0.9093
# Epoch 103/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0584 - accuracy: 0.9859 - val_loss: 0.3693 - val_accuracy: 0.9206
# Epoch 104/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0539 - accuracy: 0.9880 - val_loss: 0.3946 - val_accuracy: 0.9116
# Epoch 105/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0609 - accuracy: 0.9862 - val_loss: 0.4664 - val_accuracy: 0.9093
# Epoch 106/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0425 - accuracy: 0.9915 - val_loss: 0.3854 - val_accuracy: 0.9138
# Epoch 107/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0590 - accuracy: 0.9859 - val_loss: 0.7228 - val_accuracy: 0.8458
# Epoch 108/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0403 - accuracy: 0.9919 - val_loss: 0.5953 - val_accuracy: 0.8934
# Epoch 109/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0621 - accuracy: 0.9850 - val_loss: 0.5468 - val_accuracy: 0.9093
# Epoch 110/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0617 - accuracy: 0.9862 - val_loss: 0.4153 - val_accuracy: 0.9206
# Epoch 111/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0527 - accuracy: 0.9877 - val_loss: 0.4877 - val_accuracy: 0.9116
# Epoch 112/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0299 - accuracy: 0.9962 - val_loss: 0.5880 - val_accuracy: 0.9093
# Epoch 113/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0647 - accuracy: 0.9860 - val_loss: 0.7532 - val_accuracy: 0.8571
# Epoch 114/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0665 - accuracy: 0.9831 - val_loss: 0.5022 - val_accuracy: 0.9161
# Epoch 115/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0358 - accuracy: 0.9933 - val_loss: 0.6579 - val_accuracy: 0.8662
# Epoch 116/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0452 - accuracy: 0.9910 - val_loss: 0.5548 - val_accuracy: 0.9206
# Epoch 117/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0701 - accuracy: 0.9821 - val_loss: 0.4159 - val_accuracy: 0.9161
# Epoch 118/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0536 - accuracy: 0.9891 - val_loss: 0.4471 - val_accuracy: 0.9184
# Epoch 119/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0458 - accuracy: 0.9901 - val_loss: 0.4450 - val_accuracy: 0.9161
# Epoch 120/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0591 - accuracy: 0.9866 - val_loss: 0.4488 - val_accuracy: 0.9161
# Epoch 121/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0206 - accuracy: 0.9986 - val_loss: 0.5246 - val_accuracy: 0.9161
# Epoch 122/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0441 - accuracy: 0.9928 - val_loss: 1.0282 - val_accuracy: 0.8413
# Epoch 123/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0621 - accuracy: 0.9836 - val_loss: 0.4854 - val_accuracy: 0.9116
# Epoch 124/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0461 - accuracy: 0.9904 - val_loss: 0.4931 - val_accuracy: 0.9116
# Epoch 125/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0513 - accuracy: 0.9876 - val_loss: 0.4605 - val_accuracy: 0.9161
# Epoch 126/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0446 - accuracy: 0.9909 - val_loss: 0.4276 - val_accuracy: 0.9070
# Epoch 127/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0562 - accuracy: 0.9877 - val_loss: 0.4540 - val_accuracy: 0.9161
# Epoch 128/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.5347 - val_accuracy: 0.9229
# Epoch 129/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0784 - accuracy: 0.9825 - val_loss: 0.4652 - val_accuracy: 0.9093
# Epoch 130/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0357 - accuracy: 0.9940 - val_loss: 0.7452 - val_accuracy: 0.8639
# Epoch 131/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0419 - accuracy: 0.9910 - val_loss: 0.4861 - val_accuracy: 0.9252
# Epoch 132/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.5715 - val_accuracy: 0.9184
# Epoch 133/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0696 - accuracy: 0.9847 - val_loss: 0.4289 - val_accuracy: 0.9161
# Epoch 134/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0427 - accuracy: 0.9904 - val_loss: 0.6377 - val_accuracy: 0.9161
# Epoch 135/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0534 - accuracy: 0.9884 - val_loss: 0.7011 - val_accuracy: 0.8821
# Epoch 136/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0313 - accuracy: 0.9952 - val_loss: 0.4795 - val_accuracy: 0.9206
# Epoch 137/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0540 - accuracy: 0.9889 - val_loss: 0.4041 - val_accuracy: 0.9206
# Epoch 138/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0449 - accuracy: 0.9908 - val_loss: 0.4568 - val_accuracy: 0.9138
# Epoch 139/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0377 - accuracy: 0.9928 - val_loss: 0.4777 - val_accuracy: 0.9138
# Epoch 140/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0560 - accuracy: 0.9874 - val_loss: 0.4022 - val_accuracy: 0.9161
# Epoch 141/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0453 - accuracy: 0.9922 - val_loss: 0.3530 - val_accuracy: 0.9093
# Epoch 142/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0349 - accuracy: 0.9940 - val_loss: 0.4723 - val_accuracy: 0.9252
# Epoch 143/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0429 - accuracy: 0.9921 - val_loss: 0.4482 - val_accuracy: 0.9320
# Epoch 144/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0465 - accuracy: 0.9907 - val_loss: 0.5057 - val_accuracy: 0.9002
# Epoch 145/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0404 - accuracy: 0.9927 - val_loss: 0.9063 - val_accuracy: 0.8209
# Epoch 146/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0466 - accuracy: 0.9920 - val_loss: 0.4162 - val_accuracy: 0.9342
# Epoch 147/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.4799 - val_accuracy: 0.9297
# Epoch 148/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0701 - accuracy: 0.9858 - val_loss: 0.3819 - val_accuracy: 0.9116
# Epoch 149/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0374 - accuracy: 0.9941 - val_loss: 0.3808 - val_accuracy: 0.9116
# Epoch 150/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0432 - accuracy: 0.9914 - val_loss: 0.4883 - val_accuracy: 0.9229
# Epoch 151/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0395 - accuracy: 0.9932 - val_loss: 0.4707 - val_accuracy: 0.9320
# Epoch 152/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.5263 - val_accuracy: 0.9365
# Epoch 153/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.5928 - val_accuracy: 0.9274
# Epoch 154/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.6769 - val_accuracy: 0.9388
# Epoch 155/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0640 - accuracy: 0.9868 - val_loss: 0.4070 - val_accuracy: 0.9274
# Epoch 156/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0378 - accuracy: 0.9922 - val_loss: 0.4263 - val_accuracy: 0.9252
# Epoch 157/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.4898 - val_accuracy: 0.9320
# Epoch 158/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.5643 - val_accuracy: 0.9320
# Epoch 159/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.6771 - val_accuracy: 0.9274
# Epoch 160/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0851 - accuracy: 0.9801 - val_loss: 0.5059 - val_accuracy: 0.9184
# Epoch 161/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0570 - accuracy: 0.9877 - val_loss: 0.3786 - val_accuracy: 0.9161
# Epoch 162/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0380 - accuracy: 0.9921 - val_loss: 0.3897 - val_accuracy: 0.9252
# Epoch 163/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0219 - accuracy: 0.9980 - val_loss: 0.4721 - val_accuracy: 0.9297
# Epoch 164/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.5286 - val_accuracy: 0.9297
# Epoch 165/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.5915 - val_accuracy: 0.9274
# Epoch 166/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0590 - accuracy: 0.9889 - val_loss: 0.3345 - val_accuracy: 0.9116
# Epoch 167/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0375 - accuracy: 0.9937 - val_loss: 0.4153 - val_accuracy: 0.9320
# Epoch 168/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.5012 - val_accuracy: 0.9297
# Epoch 169/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.5616 - val_accuracy: 0.9342
# Epoch 170/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.6518 - val_accuracy: 0.9229
# Epoch 171/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0815 - accuracy: 0.9817 - val_loss: 0.4581 - val_accuracy: 0.9161
# Epoch 172/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0201 - accuracy: 0.9985 - val_loss: 0.4119 - val_accuracy: 0.9297
# Epoch 173/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0468 - accuracy: 0.9897 - val_loss: 0.6647 - val_accuracy: 0.9070
# Epoch 174/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0591 - accuracy: 0.9855 - val_loss: 0.4151 - val_accuracy: 0.9297
# Epoch 175/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0158 - accuracy: 0.9995 - val_loss: 0.9065 - val_accuracy: 0.8662
# Epoch 176/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0679 - accuracy: 0.9846 - val_loss: 0.3524 - val_accuracy: 0.9365
# Epoch 177/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0358 - accuracy: 0.9941 - val_loss: 0.4088 - val_accuracy: 0.9116
# Epoch 178/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0146 - accuracy: 0.9999 - val_loss: 0.4866 - val_accuracy: 0.9229
# Epoch 179/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.5480 - val_accuracy: 0.9206
# Epoch 180/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.5909 - val_accuracy: 0.9274
# Epoch 181/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.6502 - val_accuracy: 0.9138
# Epoch 182/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0747 - accuracy: 0.9839 - val_loss: 0.4921 - val_accuracy: 0.9116
# Epoch 183/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0295 - accuracy: 0.9959 - val_loss: 0.4671 - val_accuracy: 0.9252
# Epoch 184/250
# 1326/1326 [==============================] - 16s 12ms/step - loss: 0.0373 - accuracy: 0.9942 - val_loss: 0.6519 - val_accuracy: 0.8005
# 14/14 [==============================] - 1s 54ms/step - loss: 1.0087 - accuracy: 0.9097
# 14/14 [==============================] - 0s 13ms/step
#               precision    recall  f1-score   support
#
#            0       0.90      0.71      0.79        51
#            1       0.97      0.97      0.97        39
#            2       0.91      0.97      0.94        73
#            3       0.76      0.81      0.79        27
#            4       0.90      0.88      0.89        49
#            5       0.90      0.97      0.94        38
#            6       0.94      0.87      0.90        52
#            7       0.93      1.00      0.96        64
#            8       0.92      0.94      0.93        50
#
#     accuracy                           0.91       443
#    macro avg       0.90      0.90      0.90       443
# weighted avg       0.91      0.91      0.91       443
